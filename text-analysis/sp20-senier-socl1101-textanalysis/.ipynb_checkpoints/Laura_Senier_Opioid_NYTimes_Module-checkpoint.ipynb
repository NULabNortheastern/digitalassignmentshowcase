# %% [markdown]
# # Jeff Sternberg, Intro to Sociology, Laura Senier, Spring 2020

# %% [markdown]
# ## Using the NYTimes Article API to Create a Corpus on the Coverage of the Opioid Epidemic:
# ## An introduction to APIs, JSON, Data Types, and Digital Research Methods
#
# Using the *New York Times* API, we will explore the coverage of the Opioid Epidemic from 2010 to the present, showing you how to use the API to start a query, then show you how we go from unstructrued to structured data, providing examples of what we can do and say with this data. Some of these examples include graphing the number of opioid related article counts by year and tracking and ploting the frequency of key words used to frame and tag each of these articles.
#
# We will finish by showing you how to take the text from each article and save it as a .txt file to use in further text analysis with Lexos.

# %% [markdown]
# ### Importing Libraries to Handle APIs

# %%
# Import required libraries
from __future__ import division
import requests
import json
import math
import matplotlib.pyplot as plt
import time
import pandas
import csv
import seaborn as sns
# %matplotlib inline

# %% [markdown]
# ## Searching for Stories about Opioids

# %%
# set key
key = "Your_Key"

# set base url
base_url = "https://api.nytimes.com/svc/search/v2/articlesearch.json"

#set range for our year
year_range = range(2010, 2020)

#create empty list varible
year_tuple = list()
data_list = list()
for year in year_range:
    print(year)

    # set search parameters
    search_params = {"q": "opioid",
                    "api-key": key,
                    "begin_date": str(year)+"0101",  # create year range from the element variable
                    "end_date": str(year)+"1231"}

    # make request
    r = requests.get(base_url, params=search_params)

    # wait 3 seconds for the GET request
    time.sleep(3)

    # convert to a dictionary
    data = json.loads(r.text)
    data_list.append(data)

    # get number of hits
    hits = data['response']['meta']['hits']
    print("number of hits: ", str(hits))
    year_tuple.append(tuple((year, hits)))
# Out:
# 2010
# number of hits:  39
# 2011
# number of hits:  58
# 2012
# number of hits:  66
# 2013
# number of hits:  74
# 2014
# number of hits:  103
# 2015
# number of hits:  91
# 2016
# number of hits:  282
# 2017
# number of hits:  542
# 2018
# number of hits:  753
# 2019
# number of hits:  687

# %% [markdown]
# ## Plotting the Number of Articles on Opioids by Year

# %%
df_years = pandas.DataFrame(year_tuple, columns = ["year", "count"])
df_years
# Out:
#    year  count
# 0  2010     39
# 1  2011     58
# 2  2012     66
# 3  2013     74
# 4  2014    103
# 5  2015     91
# 6  2016    282
# 7  2017    542
# 8  2018    753
# 9  2019    687

# %%
sns.pointplot(x='year', y='count', data = df_years)

# %% [markdown]
# ## What's in the Data the API gives back to Us?
#
# For each call that we did above, we pulled the first page of queries for each year, meaning that the data we pulled has all of the data for the first ten articles in each year. We have then 100 total articles (not the full amount that was used to create the plot above) with 10 articles per year.
#
# We could change our original query and code for the NYTimes Article API to pull every page from each year so we had the full population of articles to make our corpus.
#
# ### What is in the Data we pulled and what can we do with it?

# %%
#Let's look at what is in the first page of the data we scraped from the New York Times, 
#looking at the 10 most relevant articles for our opioids serarch in 2010.

data_list[0]
# Out:
# {'copyright': 'Copyright (c) 2020 The New York Times Company. All Rights Reserved.',
#  'response': {'docs': [{'_id': 'nyt://article/d163a755-71d8-5fdb-a9e5-55b6560bf2f3',
#     'abstract': 'A review cited a higher risk of bone fracture, heart attack and death with use of narcotic-based drugs.',
#     'byline': {'organization': None,
#      'original': 'By Barry Meier',
#      'person': [{'firstname': 'Barry',
#        'lastname': 'Meier',
#        'middlename': None,
#        'organization': '',
#        'qualifier': None,
#        'rank': 1,
#        'role': 'reported',
#        'title': None}]},
#     'document_type': 'article',
#     'headline': {'content_kicker': None,
#      'kicker': None,
#      'main': 'Narcotic Painkillers May Pose Danger to Elderly Patients, Study Says',
#      'name': None,
#      'print_headline': 'Narcotic Painkillers, Thought Safer for Elderly Patients, May Pose More Risk, Study Says',
#      'seo': None,
#      'sub': None},
#     'keywords': [{'major': 'N',
#       'name': 'subject',
#       'rank': 1,
#       'value': 'ARTHRITIS AND RHEUMATISM'},
#      {'major': 'N', 'name': 'subject', 'rank': 2, 'value': 'Elderly'},
#      {'major': 'N',
#       'name': 'subject',
#       'rank': 3,
#       'value': 'Drugs (Pharmaceuticals)'},
#      {'major': 'N',
#       'name': 'subject',
#       'rank': 4,
#       'value': 'Pain-Relieving Drugs'}],
#     'lead_paragraph': ' Older patients with arthritis who take narcotic-based drugs to relieve pain face a higher risk of bone fracture, heart attack and death when compared to those taking non-narcotic drugs, according to a government-financed study published Monday.',
#     'multimedia': [],
#     'news_desk': 'Business',
#     'print_page': '3',
#     'print_section': 'B',
#     'pub_date': '2010-12-13T20:08:40+0000',
#     'section_name': 'Health',
#     'snippet': 'A review cited a higher risk of bone fracture, heart attack and death with use of narcotic-based drugs.',
#     'source': 'The New York Times',
#     'type_of_material': 'News',
#     'uri': 'nyt://article/d163a755-71d8-5fdb-a9e5-55b6560bf2f3',
#     'web_url': 'https://www.nytimes.com/2010/12/14/health/14drug.html',
#     'word_count': 635},
#    {'_id': 'nyt://article/d0a79639-2036-553e-94f9-6f2693724263',
#     'abstract': 'Workplace testing is drawing complaints from employees who say they should not be fired for taking legal drugs.',
#     'byline': {'organization': None,
#      'original': 'By Katie Zezima and Abby Goodnough',
#      'person': [{'firstname': 'Katie',
#        'lastname': 'Zezima',
#        'middlename': None,
#        'organization': '',
#        'qualifier': None,
#        'rank': 1,
#        'role': 'reported',
#        'title': None},
#       {'firstname': 'Abby',
#        'lastname': 'Goodnough',
#        'middlename': None,
#        'organization': '',
#        'qualifier': None,
#        'rank': 2,
#        'role': 'reported',
#        'title': None}]},
#     'document_type': 'article',
#     'headline': {'content_kicker': None,
#      'kicker': None,
#      'main': 'Drug Testing Poses Quandary for Employers',
#      'name': None,
#      'print_headline': 'Testing for Prescription Drugs Poses Quandary for Employers',
#      'seo': None,
#      'sub': None},
#     'keywords': [{'major': 'N',
#       'name': 'organizations',
#       'rank': 1,
#       'value': 'DURA AUTOMOTIVE SYSTEMS INCORPORATED'},
#      {'major': 'N',
#       'name': 'subject',
#       'rank': 2,
#       'value': 'Tests and Testing'},
#      {'major': 'N',
#       'name': 'subject',
#       'rank': 3,
#       'value': 'Pain-Relieving Drugs'},
#      {'major': 'N',
#       'name': 'subject',
#       'rank': 4,
#       'value': 'ACCIDENTS AND SAFETY'},
#      {'major': 'N',
#       'name': 'subject',
#       'rank': 5,
#       'value': 'Drugs (Pharmaceuticals)'},
#      {'major': 'N',
#       'name': 'subject',
#       'rank': 6,
#       'value': 'Drug Abuse and Traffic'},
#      {'major': 'N', 'name': 'subject', 'rank': 7, 'value': 'Labor and Jobs'}],
#     'lead_paragraph': 'LAWRENCEBURG, Tenn. \x97 The news, delivered in a phone call, left Sue Bates aghast: she was losing her job of 22 years after testing positive for a legally prescribed drug. ',
#     'multimedia': [{'caption': None,
#       'credit': None,
#       'crop_name': 'articleLarge',
#       'height': 330,
#       'legacy': {'xlarge': 'images/2010/10/25/us/25drugs_337-span/JP-DRUGS-2-articleLarge.jpg',
#        'xlargeheight': 330,
#        'xlargewidth': 600},
#       'rank': 0,
#       'subType': 'xlarge',
#       'subtype': 'xlarge',
#       'type': 'image',
#       'url': 'images/2010/10/25/us/25drugs_337-span/JP-DRUGS-2-articleLarge.jpg',
#       'width': 600},
#      {'caption': None,
#       'credit': None,
#       'crop_name': 'jumbo',
#       'height': 677,
#       'legacy': {},
#       'rank': 0,
#       'subType': 'jumbo',
#       'subtype': 'jumbo',
#       'type': 'image',
#       'url': 'images/2010/10/25/us/25drugs_337-span/JP-DRUGS-2-jumbo.jpg',
#       'width': 1024},
#      {'caption': None,
#       'credit': None,
#       'crop_name': 'popup',
#       'height': 429,
#       'legacy': {},
#       'rank': 0,
#       'subType': 'popup',
#       'subtype': 'popup',
#       'type': 'image',
#       'url': 'images/2010/10/25/us/25drugs_337-span/JP-DRUGS-2-popup.jpg',
#       'width': 650},
#      {'caption': None,
#       'credit': None,
#       'crop_name': 'articleInline',
#       'height': 126,
#       'legacy': {},
#       'rank': 0,
#       'subType': 'articleInline',
#       'subtype': 'articleInline',
#       'type': 'image',
#       'url': 'images/2010/10/25/us/25drugs_337-span/JP-DRUGS-2-articleInline.jpg',
#       'width': 190},
#      {'caption': None,
#       'credit': None,
#       'crop_name': 'sfSpan',
#       'height': 250,
#       'legacy': {},
#       'rank': 0,
#       'subType': 'sfSpan',
#       'subtype': 'sfSpan',
#       'type': 'image',
#       'url': 'images/2010/10/25/us/25drugs_337-span/JP-DRUGS-2-sfSpan.jpg',
#       'width': 395},
#      {'caption': None,
#       'credit': None,
#       'crop_name': 'thumbStandard',
#       'height': 75,
#       'legacy': {'thumbnail': 'images/2010/10/25/us/25drugs_337-span/JP-DRUGS-2-thumbStandard.jpg',
#        'thumbnailheight': 75,
#        'thumbnailwidth': 75},
#       'rank': 0,
#       'subType': 'thumbnail',
#       'subtype': 'thumbnail',
#       'type': 'image',
#       'url': 'images/2010/10/25/us/25drugs_337-span/JP-DRUGS-2-thumbStandard.jpg',
#       'width': 75}],
#     'news_desk': 'National',
#     'print_page': '1',
#     'print_section': 'A',
#     'pub_date': '2010-10-24T23:38:15+0000',
#     'section_name': 'U.S.',
#     'snippet': 'Workplace testing is drawing complaints from employees who say they should not be fired for taking legal drugs.',
#     'source': 'The New York Times',
#     'type_of_material': 'News',
#     'uri': 'nyt://article/d0a79639-2036-553e-94f9-6f2693724263',
#     'web_url': 'https://www.nytimes.com/2010/10/25/us/25drugs.html',
#     'word_count': 2294},
#    {'_id': 'nyt://article/32522fc0-ad24-56bc-b2f6-ed832f9b667e',
#     'abstract': 'Drug users are breaking into people’s homes in search of prescription painkillers and other medications.',
#     'byline': {'organization': None,
#      'original': 'By Abby Goodnough',
#      'person': [{'firstname': 'Abby',
#        'lastname': 'Goodnough',
#        'middlename': None,
#        'organization': '',
#        'qualifier': None,
#        'rank': 1,
#        'role': 'reported',
#        'title': None}]},
#     'document_type': 'article',
#     'headline': {'content_kicker': None,
#      'kicker': None,
#      'main': 'A Wave of Addiction and Crime, with the Medicine Cabinet to Blame',
#      'name': None,
#      'print_headline': 'A Wave of Addiction and Crime, With the Medicine Cabinet to Blame',
#      'seo': None,
#      'sub': None},
#     'keywords': [{'major': 'N',
#       'name': 'subject',
#       'rank': 1,
#       'value': 'Drug Abuse and Traffic'},
#      {'major': 'N',
#       'name': 'subject',
#       'rank': 2,
#       'value': 'Drugs (Pharmaceuticals)'},
#      {'major': 'N',
#       'name': 'organizations',
#       'rank': 3,
#       'value': 'Drug Enforcement Administration'},
#      {'major': 'N',
#       'name': 'subject',
#       'rank': 4,
#       'value': 'Pain-Relieving Drugs'}],
#     'lead_paragraph': 'BOSTON \x97 Police departments have collected thousands of handguns through buy-back programs in communities throughout the country. Now they want the contents of your medicine cabinet.',
#     'multimedia': [{'caption': None,
#       'credit': None,
#       'crop_name': 'articleLarge',
#       'height': 330,
#       'legacy': {'xlarge': 'images/2010/09/24/us/24drugs_395-inline/24drugs_395-inline-articleLarge.jpg',
#        'xlargeheight': 330,
#        'xlargewidth': 600},
#       'rank': 0,
#       'subType': 'xlarge',
#       'subtype': 'xlarge',
#       'type': 'image',
#       'url': 'images/2010/09/24/us/24drugs_395-inline/24drugs_395-inline-articleLarge.jpg',
#       'width': 600},
#      {'caption': None,
#       'credit': None,
#       'crop_name': 'jumbo',
#       'height': 760,
#       'legacy': {},
#       'rank': 0,
#       'subType': 'jumbo',
#       'subtype': 'jumbo',
#       'type': 'image',
#       'url': 'images/2010/09/24/us/24drugs_395-inline/24drugs_395-span-jumbo.jpg',
#       'width': 1024},
#      {'caption': None,
#       'credit': None,
#       'crop_name': 'popup',
#       'height': 482,
#       'legacy': {},
#       'rank': 0,
#       'subType': 'popup',
#       'subtype': 'popup',
#       'type': 'image',
#       'url': 'images/2010/09/24/us/24drugs_395-inline/24drugs_395-span-popup.jpg',
#       'width': 650},
#      {'caption': None,
#       'credit': None,
#       'crop_name': 'articleInline',
#       'height': 140,
#       'legacy': {},
#       'rank': 0,
#       'subType': 'articleInline',
#       'subtype': 'articleInline',
#       'type': 'image',
#       'url': 'images/2010/09/24/us/24drugs_395-inline/24drugs_395-span-articleInline.jpg',
#       'width': 190},
#      {'caption': None,
#       'credit': None,
#       'crop_name': 'sfSpan',
#       'height': 270,
#       'legacy': {},
#       'rank': 0,
#       'subType': 'sfSpan',
#       'subtype': 'sfSpan',
#       'type': 'image',
#       'url': 'images/2010/09/24/us/24drugs_395-inline/24drugs_395-span-sfSpan.jpg',
#       'width': 395},
#      {'caption': None,
#       'credit': None,
#       'crop_name': 'thumbStandard',
#       'height': 75,
#       'legacy': {'thumbnail': 'images/2010/09/24/us/24drugs_395-inline/24drugs_395-span-thumbStandard.jpg',
#        'thumbnailheight': 75,
#        'thumbnailwidth': 75},
#       'rank': 0,
#       'subType': 'thumbnail',
#       'subtype': 'thumbnail',
#       'type': 'image',
#       'url': 'images/2010/09/24/us/24drugs_395-inline/24drugs_395-span-thumbStandard.jpg',
#       'width': 75}],
#     'news_desk': 'National',
#     'print_page': '14',
#     'print_section': 'A',
#     'pub_date': '2010-09-24T00:23:07+0000',
#     'section_name': 'U.S.',
#     'snippet': 'Drug users are breaking into people’s homes in search of prescription painkillers and other medications.',
#     'source': 'The New York Times',
#     'type_of_material': 'News',
#     'uri': 'nyt://article/32522fc0-ad24-56bc-b2f6-ed832f9b667e',
#     'web_url': 'https://www.nytimes.com/2010/09/24/us/24drugs.html',
#     'word_count': 1045},
#    {'_id': 'nyt://article/74fd453a-a318-58dc-9d42-db4b6cccca4e',
#     'abstract': 'San Francisco police officers say they are seeing more elderly, sick or disabled people selling their medications on the street.',
#     'byline': {'organization': None,
#      'original': 'By Shoshana Walter',
#      'person': [{'firstname': 'Shoshana',
#        'lastname': 'Walter',
#        'middlename': None,
#        'organization': '',
#        'qualifier': None,
#        'rank': 1,
#        'role': 'reported',
#        'title': None}]},
#     'document_type': 'article',
#     'headline': {'content_kicker': None,
#      'kicker': 'The Bay Citizen',
#      'main': 'Officers See More Sick and Elderly Selling Prescription Drugs',
#      'name': None,
#      'print_headline': 'Officers See More Sick and Elderly Selling Prescription Drugs',
#      'seo': None,
#      'sub': None},
#     'keywords': [{'major': 'N',
#       'name': 'subject',
#       'rank': 1,
#       'value': 'OxyContin (Drug)'},
#      {'major': 'N',
#       'name': 'subject',
#       'rank': 2,
#       'value': 'Pain-Relieving Drugs'},
#      {'major': 'N', 'name': 'subject', 'rank': 3, 'value': 'Elderly'},
#      {'major': 'N',
#       'name': 'subject',
#       'rank': 4,
#       'value': 'Cocaine and Crack Cocaine'},
#      {'major': 'N',
#       'name': 'glocations',
#       'rank': 5,
#       'value': 'San Francisco (Calif)'},
#      {'major': 'N',
#       'name': 'subject',
#       'rank': 6,
#       'value': 'Drug Abuse and Traffic'}],
#     'lead_paragraph': 'In Gregory Watts’s 13 years as a San Francisco police officer, he has arrested countless drug dealers. But only recently did he begin to notice that many of them resembled his grandparents.',
#     'multimedia': [{'caption': None,
#       'credit': None,
#       'crop_name': 'jumbo',
#       'height': 1024,
#       'legacy': {},
#       'rank': 0,
#       'subType': 'jumbo',
#       'subtype': 'jumbo',
#       'type': 'image',
#       'url': 'images/2010/09/19/us/19BCDEALERS/19BCDEALERS-jumbo.jpg',
#       'width': 1024},
#      {'caption': None,
#       'credit': None,
#       'crop_name': 'popup',
#       'height': 650,
#       'legacy': {},
#       'rank': 0,
#       'subType': 'popup',
#       'subtype': 'popup',
#       'type': 'image',
#       'url': 'images/2010/09/19/us/19BCDEALERS/19BCDEALERS-popup.jpg',
#       'width': 650},
#      {'caption': None,
#       'credit': None,
#       'crop_name': 'articleInline',
#       'height': 190,
#       'legacy': {},
#       'rank': 0,
#       'subType': 'articleInline',
#       'subtype': 'articleInline',
#       'type': 'image',
#       'url': 'images/2010/09/19/us/19BCDEALERS/19BCDEALERS-articleInline.jpg',
#       'width': 190}],
#     'news_desk': 'National',
#     'print_page': '35A',
#     'print_section': 'A',
#     'pub_date': '2010-09-18T23:36:47+0000',
#     'section_name': 'U.S.',
#     'snippet': 'San Francisco police officers say they are seeing more elderly, sick or disabled people selling their medications on the street.',
#     'source': 'The New York Times',
#     'type_of_material': 'News',
#     'uri': 'nyt://article/74fd453a-a318-58dc-9d42-db4b6cccca4e',
#     'web_url': 'https://www.nytimes.com/2010/09/19/us/19bcdealers.html',
#     'word_count': 476},
#    {'_id': 'nyt://article/77649ce3-0a58-56fe-8129-fda083e69738',
#     'abstract': 'An expansive mix of medical reportage, history and memoir explores our relationship to pain.',
#     'byline': {'organization': None,
#      'original': 'By Robin Romm',
#      'person': [{'firstname': 'Robin',
#        'lastname': 'Romm',
#        'middlename': None,
#        'organization': '',
#        'qualifier': None,
#        'rank': 1,
#        'role': 'reported',
#        'title': None}]},
#     'document_type': 'article',
#     'headline': {'content_kicker': None,
#      'kicker': None,
#      'main': 'Where It Hurts',
#      'name': None,
#      'print_headline': 'Where It Hurts',
#      'seo': None,
#      'sub': None},
#     'keywords': [{'major': 'N',
#       'name': 'subject',
#       'rank': 1,
#       'value': 'Pain-Relieving Drugs'},
#      {'major': 'N', 'name': 'subject', 'rank': 2, 'value': 'Pain'},
#      {'major': 'N',
#       'name': 'subject',
#       'rank': 3,
#       'value': 'Books and Literature'},
#      {'major': 'N',
#       'name': 'subject',
#       'rank': 4,
#       'value': 'Medicine and Health'},
#      {'major': 'N',
#       'name': 'subject',
#       'rank': 5,
#       'value': 'ANESTHESIA AND ANESTHETICS'},
#      {'major': 'N',
#       'name': 'persons',
#       'rank': 6,
#       'value': 'Thernstrom, Melanie'}],
#     'lead_paragraph': 'A simple understanding of pain would be this: It’s a biological response to injury or disease. Treat the cause and the pain abates. The body, after all, is a relatively efficient machine. But what happens when the wound won’t heal? And what if pain doesn’t stem from injury or disease, but is itself the problem?',
#     'multimedia': [{'caption': None,
#       'credit': None,
#       'crop_name': 'jumbo',
#       'height': 949,
#       'legacy': {},
#       'rank': 0,
#       'subType': 'jumbo',
#       'subtype': 'jumbo',
#       'type': 'image',
#       'url': 'images/2010/08/29/books/review/Romm-t_CA0/Romm-t_CA0-jumbo.jpg',
#       'width': 964},
#      {'caption': None,
#       'credit': None,
#       'crop_name': 'popup',
#       'height': 640,
#       'legacy': {},
#       'rank': 0,
#       'subType': 'popup',
#       'subtype': 'popup',
#       'type': 'image',
#       'url': 'images/2010/08/29/books/review/Romm-t_CA0/Romm-t_CA0-popup.jpg',
#       'width': 650},
#      {'caption': None,
#       'credit': None,
#       'crop_name': 'articleInline',
#       'height': 187,
#       'legacy': {},
#       'rank': 0,
#       'subType': 'articleInline',
#       'subtype': 'articleInline',
#       'type': 'image',
#       'url': 'images/2010/08/29/books/review/Romm-t_CA0/Romm-t_CA0-articleInline.jpg',
#       'width': 190},
#      {'caption': None,
#       'credit': None,
#       'crop_name': 'thumbStandard',
#       'height': 75,
#       'legacy': {'thumbnail': 'images/2010/08/29/books/review/Romm-t_CA0/Romm-t_CA0-thumbStandard.jpg',
#        'thumbnailheight': 75,
#        'thumbnailwidth': 75},
#       'rank': 0,
#       'subType': 'thumbnail',
#       'subtype': 'thumbnail',
#       'type': 'image',
#       'url': 'images/2010/08/29/books/review/Romm-t_CA0/Romm-t_CA0-thumbStandard.jpg',
#       'width': 75}],
#     'news_desk': 'BookReview',
#     'print_page': '12',
#     'print_section': 'BR',
#     'pub_date': '2010-08-26T21:14:01+0000',
#     'section_name': 'Books',
#     'snippet': 'An expansive mix of medical reportage, history and memoir explores our relationship to pain.',
#     'source': 'The New York Times',
#     'subsection_name': 'Book Review',
#     'type_of_material': 'Review',
#     'uri': 'nyt://article/77649ce3-0a58-56fe-8129-fda083e69738',
#     'web_url': 'https://www.nytimes.com/2010/08/29/books/review/Romm-t.html',
#     'word_count': 1180},
#    {'_id': 'nyt://article/794b63ea-9cdc-5384-8d69-ce70b4fad598',
#     'abstract': 'Regulators in Washington State are attempting to stem what some see as the excessive use of prescribed narcotics.',
#     'byline': {'organization': None,
#      'original': 'By Barry Meier',
#      'person': [{'firstname': 'Barry',
#        'lastname': 'Meier',
#        'middlename': None,
#        'organization': '',
#        'qualifier': None,
#        'rank': 1,
#        'role': 'reported',
#        'title': None}]},
#     'document_type': 'article',
#     'headline': {'content_kicker': None,
#      'kicker': None,
#      'main': 'Move to Restrict Pain Killers Puts Onus on Doctors',
#      'name': None,
#      'print_headline': 'When Pain Drugs Hurt',
#      'seo': None,
#      'sub': None},
#     'keywords': [{'major': 'N',
#       'name': 'subject',
#       'rank': 1,
#       'value': 'Doctors'},
#      {'major': 'N',
#       'name': 'glocations',
#       'rank': 2,
#       'value': 'Washington (State)'},
#      {'major': 'N',
#       'name': 'subject',
#       'rank': 3,
#       'value': 'Drugs (Pharmaceuticals)'},
#      {'major': 'N',
#       'name': 'subject',
#       'rank': 4,
#       'value': 'Regulation and Deregulation of Industry'},
#      {'major': 'N',
#       'name': 'subject',
#       'rank': 5,
#       'value': 'Pain-Relieving Drugs'}],
#     'lead_paragraph': 'In an unusual move, a state government is developing regulations meant to stop doctors from prescribing higher doses of powerful \x97 and often dangerous \x97 pain killers for patients who are not benefiting from them.',
#     'multimedia': [{'caption': None,
#       'credit': None,
#       'crop_name': 'articleLarge',
#       'height': 350,
#       'legacy': {'xlarge': 'images/2010/07/29/business/29pain1/29pain1-articleLarge.jpg',
#        'xlargeheight': 350,
#        'xlargewidth': 600},
#       'rank': 0,
#       'subType': 'xlarge',
#       'subtype': 'xlarge',
#       'type': 'image',
#       'url': 'images/2010/07/29/business/29pain1/29pain1-articleLarge.jpg',
#       'width': 600},
#      {'caption': None,
#       'credit': None,
#       'crop_name': 'jumbo',
#       'height': 683,
#       'legacy': {},
#       'rank': 0,
#       'subType': 'jumbo',
#       'subtype': 'jumbo',
#       'type': 'image',
#       'url': 'images/2010/07/29/business/29pain1/29pain1-jumbo.jpg',
#       'width': 1024},
#      {'caption': None,
#       'credit': None,
#       'crop_name': 'popup',
#       'height': 433,
#       'legacy': {},
#       'rank': 0,
#       'subType': 'popup',
#       'subtype': 'popup',
#       'type': 'image',
#       'url': 'images/2010/07/29/business/29pain1/29pain1-popup.jpg',
#       'width': 650},
#      {'caption': None,
#       'credit': None,
#       'crop_name': 'articleInline',
#       'height': 127,
#       'legacy': {},
#       'rank': 0,
#       'subType': 'articleInline',
#       'subtype': 'articleInline',
#       'type': 'image',
#       'url': 'images/2010/07/29/business/29pain1/29pain1-articleInline.jpg',
#       'width': 190},
#      {'caption': None,
#       'credit': None,
#       'crop_name': 'sfSpan',
#       'height': 250,
#       'legacy': {},
#       'rank': 0,
#       'subType': 'sfSpan',
#       'subtype': 'sfSpan',
#       'type': 'image',
#       'url': 'images/2010/07/29/business/29pain1/29pain1-sfSpan.jpg',
#       'width': 395},
#      {'caption': None,
#       'credit': None,
#       'crop_name': 'thumbStandard',
#       'height': 75,
#       'legacy': {'thumbnail': 'images/2010/07/29/business/29pain1/29pain1-thumbStandard.jpg',
#        'thumbnailheight': 75,
#        'thumbnailwidth': 75},
#       'rank': 0,
#       'subType': 'thumbnail',
#       'subtype': 'thumbnail',
#       'type': 'image',
#       'url': 'images/2010/07/29/business/29pain1/29pain1-thumbStandard.jpg',
#       'width': 75}],
#     'news_desk': 'Business',
#     'print_page': '1',
#     'print_section': 'B',
#     'pub_date': '2010-07-28T16:23:30+0000',
#     'section_name': 'Business Day',
#     'snippet': 'Regulators in Washington State are attempting to stem what some see as the excessive use of prescribed narcotics.',
#     'source': 'The New York Times',
#     'type_of_material': 'News',
#     'uri': 'nyt://article/794b63ea-9cdc-5384-8d69-ce70b4fad598',
#     'web_url': 'https://www.nytimes.com/2010/07/29/business/29pain.html',
#     'word_count': 1108},
#    {'_id': 'nyt://article/94df1e7d-54f6-5dcc-abd1-44971feb5d32',
#     'abstract': 'Mr. Lotsof’s belief that ibogaine could cure addiction to heroin persuaded the F.D.A. to approve a clinical trial, but the substance remains banned in the United States.',
#     'byline': {'organization': None,
#      'original': 'By Dennis Hevesi',
#      'person': [{'firstname': 'Dennis',
#        'lastname': 'Hevesi',
#        'middlename': None,
#        'organization': '',
#        'qualifier': None,
#        'rank': 1,
#        'role': 'reported',
#        'title': None}]},
#     'document_type': 'article',
#     'headline': {'content_kicker': None,
#      'kicker': None,
#      'main': 'Howard Lotsof Dies at 66; Saw Drug Cure in a Plant',
#      'name': None,
#      'print_headline': 'Howard Lotsof, 66; Saw Drug Cure in a Plant\n',
#      'seo': None,
#      'sub': None},
#     'keywords': [{'major': 'N',
#       'name': 'subject',
#       'rank': 1,
#       'value': 'Medicine and Health'},
#      {'major': 'N',
#       'name': 'subject',
#       'rank': 2,
#       'value': 'Drugs (Pharmaceuticals)'},
#      {'major': 'N',
#       'name': 'subject',
#       'rank': 3,
#       'value': 'Deaths (Obituaries)'}],
#     'lead_paragraph': 'Howard Lotsof was 19, addicted to heroin and searching for a new high in 1962 when he swallowed a bitter-tasting white powder taken from an exotic West African shrub. ',
#     'multimedia': [{'caption': None,
#       'credit': None,
#       'crop_name': 'popup',
#       'height': 450,
#       'legacy': {},
#       'rank': 0,
#       'subType': 'popup',
#       'subtype': 'popup',
#       'type': 'image',
#       'url': 'images/2010/02/17/us/17lotsofimg/17lotsofimg-popup.jpg',
#       'width': 303},
#      {'caption': None,
#       'credit': None,
#       'crop_name': 'articleInline',
#       'height': 266,
#       'legacy': {},
#       'rank': 0,
#       'subType': 'articleInline',
#       'subtype': 'articleInline',
#       'type': 'image',
#       'url': 'images/2010/02/17/us/17lotsofimg/17lotsofimg-articleInline.jpg',
#       'width': 190},
#      {'caption': None,
#       'credit': None,
#       'crop_name': 'thumbStandard',
#       'height': 75,
#       'legacy': {'thumbnail': 'images/2010/02/17/us/17lotsofimg/17lotsofimg-thumbStandard.jpg',
#        'thumbnailheight': 75,
#        'thumbnailwidth': 75},
#       'rank': 0,
#       'subType': 'thumbnail',
#       'subtype': 'thumbnail',
#       'type': 'image',
#       'url': 'images/2010/02/17/us/17lotsofimg/17lotsofimg-thumbStandard.jpg',
#       'width': 75}],
#     'news_desk': 'National',
#     'print_page': '25',
#     'print_section': 'A',
#     'pub_date': '2010-02-17T06:05:45+0000',
#     'section_name': 'U.S.',
#     'snippet': 'Mr. Lotsof’s belief that ibogaine could cure addiction to heroin persuaded the F.D.A. to approve a clinical trial, but the substance remains banned in the United States.',
#     'source': 'The New York Times',
#     'type_of_material': 'Obituary (Obit)',
#     'uri': 'nyt://article/94df1e7d-54f6-5dcc-abd1-44971feb5d32',
#     'web_url': 'https://www.nytimes.com/2010/02/17/us/17lotsof.html',
#     'word_count': 767},
#    {'_id': 'nyt://article/27343e57-ab0c-5d24-8493-18a5480309a9',
#     'abstract': 'Emergency room visits for nonmedical use of prescription and over-the-counter drugs doubled during a recent five-year period.',
#     'byline': {'organization': None,
#      'original': 'By Roni Caryn Rabin',
#      'person': [{'firstname': 'Roni',
#        'lastname': 'Rabin',
#        'middlename': 'Caryn',
#        'organization': '',
#        'qualifier': None,
#        'rank': 1,
#        'role': 'reported',
#        'title': None}]},
#     'document_type': 'article',
#     'headline': {'content_kicker': None,
#      'kicker': 'Vital Signs',
#      'main': 'Hazards: Emergencies Over Legal Drugs Increase',
#      'name': None,
#      'print_headline': 'HAZARDS: Sharp Rise in Abuse of Legal Drugs',
#      'seo': None,
#      'sub': None},
#     'keywords': [{'major': 'N', 'name': 'subject', 'rank': 1, 'value': 'Pain'},
#      {'major': 'N',
#       'name': 'subject',
#       'rank': 2,
#       'value': 'Drug Abuse and Traffic'},
#      {'major': 'N',
#       'name': 'subject',
#       'rank': 3,
#       'value': 'Medicine and Health'},
#      {'major': 'N',
#       'name': 'subject',
#       'rank': 4,
#       'value': 'Emergency Medical Treatment'}],
#     'lead_paragraph': 'Emergency room visits for nonmedical use of prescription and over-the-counter drugs doubled during a recent five-year-period, the Centers for Disease Control and Prevention are reporting. ',
#     'multimedia': [],
#     'news_desk': 'Science',
#     'print_page': '6',
#     'print_section': 'D',
#     'pub_date': '2010-06-21T19:06:49+0000',
#     'section_name': 'Health',
#     'snippet': 'Emergency room visits for nonmedical use of prescription and over-the-counter drugs doubled during a recent five-year period.',
#     'source': 'The New York Times',
#     'subsection_name': 'Research',
#     'type_of_material': 'News',
#     'uri': 'nyt://article/27343e57-ab0c-5d24-8493-18a5480309a9',
#     'web_url': 'https://www.nytimes.com/2010/06/22/health/research/22haza.html',
#     'word_count': 161},
#    {'_id': 'nyt://interactive/6a38ce48-ccab-540d-952b-db5e7b5275de',
#     'abstract': 'Mysterious pain, doubting doctors, depression, fatigue and brain fog — six people speak about living with fibromyalgia.',
#     'byline': {'organization': None, 'original': None, 'person': []},
#     'document_type': 'multimedia',
#     'headline': {'content_kicker': None,
#      'kicker': None,
#      'main': 'Patient Voices: Fibromyalgia',
#      'name': None,
#      'print_headline': None,
#      'seo': None,
#      'sub': None},
#     'keywords': [{'major': 'N',
#       'name': 'subject',
#       'rank': 1,
#       'value': 'Fibromyalgia'},
#      {'major': 'N',
#       'name': 'subject',
#       'rank': 2,
#       'value': 'Medicine and Health'},
#      {'major': 'N', 'name': 'subject', 'rank': 3, 'value': 'Pain'},
#      {'major': 'N',
#       'name': 'subject',
#       'rank': 4,
#       'value': 'Pain-Relieving Drugs'}],
#     'lead_paragraph': 'Mysterious pain, doubting doctors, depression, fatigue and brain fog — six people speak about living with fibromyalgia.',
#     'multimedia': [{'caption': None,
#       'credit': None,
#       'crop_name': 'thumbWide',
#       'height': 126,
#       'legacy': {'wide': 'images/2010/03/04/science/fibromyalgia_promo/fibromyalgia_promo-thumbWide.jpg',
#        'wideheight': 126,
#        'widewidth': 190},
#       'rank': 0,
#       'subType': 'wide',
#       'subtype': 'wide',
#       'type': 'image',
#       'url': 'images/2010/03/04/science/fibromyalgia_promo/fibromyalgia_promo-thumbWide.jpg',
#       'width': 190},
#      {'caption': None,
#       'credit': None,
#       'crop_name': 'blog480',
#       'height': 319,
#       'legacy': {},
#       'rank': 0,
#       'subType': 'blog480',
#       'subtype': 'blog480',
#       'type': 'image',
#       'url': 'images/2010/03/04/science/fibromyalgia_promo/fibromyalgia_promo-blogSpan.jpg',
#       'width': 480},
#      {'caption': None,
#       'credit': None,
#       'crop_name': 'popup',
#       'height': 250,
#       'legacy': {},
#       'rank': 0,
#       'subType': 'popup',
#       'subtype': 'popup',
#       'type': 'image',
#       'url': 'images/2010/03/04/science/fibromyalgia_promo/fibromyalgia_promo-sfSpan.jpg',
#       'width': 395},
#      {'caption': None,
#       'credit': None,
#       'crop_name': 'sfSpan',
#       'height': 250,
#       'legacy': {},
#       'rank': 0,
#       'subType': 'sfSpan',
#       'subtype': 'sfSpan',
#       'type': 'image',
#       'url': 'images/2010/03/04/science/fibromyalgia_promo/fibromyalgia_promo-sfSpan.jpg',
#       'width': 395},
#      {'caption': None,
#       'credit': None,
#       'crop_name': 'thumbStandard',
#       'height': 75,
#       'legacy': {'thumbnail': 'images/2010/03/04/science/fibromyalgia_promo/fibromyalgia_promo-thumbStandard.jpg',
#        'thumbnailheight': 75,
#        'thumbnailwidth': 75},
#       'rank': 0,
#       'subType': 'thumbnail',
#       'subtype': 'thumbnail',
#       'type': 'image',
#       'url': 'images/2010/03/04/science/fibromyalgia_promo/fibromyalgia_promo-thumbStandard.jpg',
#       'width': 75}],
#     'news_desk': 'Health',
#     'pub_date': '2010-03-03T17:24:34+0000',
#     'section_name': 'Health',
#     'snippet': 'Mysterious pain, doubting doctors, depression, fatigue and brain fog — six people speak about living with fibromyalgia.',
#     'source': 'The New York Times',
#     'subsection_name': 'Health Guide',
#     'type_of_material': 'Interactive Feature',
#     'uri': 'nyt://interactive/6a38ce48-ccab-540d-952b-db5e7b5275de',
#     'web_url': 'https://www.nytimes.com/interactive/2010/03/04/health/healthguide/TE_fibromyalgia.html',
#     'word_count': 0},
#    {'_id': 'nyt://article/f26da0b6-17cd-5274-8f0d-2768394ecf8f',
#     'abstract': 'The pain killer and related drugs can cause fatal heart rhythms.',
#     'byline': {'organization': None,
#      'original': 'By Duff Wilson',
#      'person': [{'firstname': 'Duff',
#        'lastname': 'Wilson',
#        'middlename': None,
#        'organization': '',
#        'qualifier': None,
#        'rank': 1,
#        'role': 'reported',
#        'title': None}]},
#     'document_type': 'article',
#     'headline': {'content_kicker': None,
#      'kicker': 'Prescriptions',
#      'main': 'Darvon Pulled From Market by F.D.A.',
#      'name': None,
#      'print_headline': None,
#      'seo': None,
#      'sub': None},
#     'keywords': [],
#     'lead_paragraph': 'The painkilling drug propoxyphene, sold under the Darvon and Darvocet brands and used by about 10 million Americans last year, will be removed from the market because of serious heart risks, the Food and Drug Administration said on Friday.',
#     'multimedia': [],
#     'news_desk': '',
#     'pub_date': '2010-11-19T19:03:09+0000',
#     'section_name': 'Health',
#     'snippet': 'The pain killer and related drugs can cause fatal heart rhythms.',
#     'source': 'The New York Times',
#     'uri': 'nyt://article/f26da0b6-17cd-5274-8f0d-2768394ecf8f',
#     'web_url': 'https://prescriptions.blogs.nytimes.com/2010/11/19/darvon-pulled-from-market-by-f-d-a/',
#     'word_count': 732}],
#   'meta': {'hits': 39, 'offset': 0, 'time': 164}},
#  'status': 'OK'}

# %%
#We see different categories represented in this output, the data nested in hierarchical sets of categories
#What categories are in the top level of our hierarchy?

for i in data_list[0]:
    print(i)
# Out:
# status
# copyright
# response

# %%
#If we look into the status category, what data is stored here, what other categories are nested below this?

print(data_list[0]["status"])
# Out:
# OK

# %%
#If we look into the copyright category, what data is stored here, what other categories are nested below this?

print(data_list[0]['copyright'])
# Out:
# Copyright (c) 2020 The New York Times Company. All Rights Reserved.

# %%
#If we look into the response category, what data is stored here, what other categories are nested below this?

print(data_list[0]['response'])
# Out:
# {'docs': [{'abstract': 'A review cited a higher risk of bone fracture, heart attack and death with use of narcotic-based drugs.', 'web_url': 'https://www.nytimes.com/2010/12/14/health/14drug.html', 'snippet': 'A review cited a higher risk of bone fracture, heart attack and death with use of narcotic-based drugs.', 'lead_paragraph': ' Older patients with arthritis who take narcotic-based drugs to relieve pain face a higher risk of bone fracture, heart attack and death when compared to those taking non-narcotic drugs, according to a government-financed study published Monday.', 'print_section': 'B', 'print_page': '3', 'source': 'The New York Times', 'multimedia': [], 'headline': {'main': 'Narcotic Painkillers May Pose Danger to Elderly Patients, Study Says', 'kicker': None, 'content_kicker': None, 'print_headline': 'Narcotic Painkillers, Thought Safer for Elderly Patients, May Pose More Risk, Study Says', 'name': None, 'seo': None, 'sub': None}, 'keywords': [{'name': 'subject', 'value': 'ARTHRITIS AND RHEUMATISM', 'rank': 1, 'major': 'N'}, {'name': 'subject', 'value': 'Elderly', 'rank': 2, 'major': 'N'}, {'name': 'subject', 'value': 'Drugs (Pharmaceuticals)', 'rank': 3, 'major': 'N'}, {'name': 'subject', 'value': 'Pain-Relieving Drugs', 'rank': 4, 'major': 'N'}], 'pub_date': '2010-12-13T20:08:40+0000', 'document_type': 'article', 'news_desk': 'Business', 'section_name': 'Health', 'byline': {'original': 'By Barry Meier', 'person': [{'firstname': 'Barry', 'middlename': None, 'lastname': 'Meier', 'qualifier': None, 'title': None, 'role': 'reported', 'organization': '', 'rank': 1}], 'organization': None}, 'type_of_material': 'News', '_id': 'nyt://article/d163a755-71d8-5fdb-a9e5-55b6560bf2f3', 'word_count': 635, 'uri': 'nyt://article/d163a755-71d8-5fdb-a9e5-55b6560bf2f3'}, {'abstract': 'Workplace testing is drawing complaints from employees who say they should not be fired for taking legal drugs.', 'web_url': 'https://www.nytimes.com/2010/10/25/us/25drugs.html', 'snippet': 'Workplace testing is drawing complaints from employees who say they should not be fired for taking legal drugs.', 'lead_paragraph': 'LAWRENCEBURG, Tenn. \x97 The news, delivered in a phone call, left Sue Bates aghast: she was losing her job of 22 years after testing positive for a legally prescribed drug. ', 'print_section': 'A', 'print_page': '1', 'source': 'The New York Times', 'multimedia': [{'rank': 0, 'subtype': 'xlarge', 'caption': None, 'credit': None, 'type': 'image', 'url': 'images/2010/10/25/us/25drugs_337-span/JP-DRUGS-2-articleLarge.jpg', 'height': 330, 'width': 600, 'legacy': {'xlarge': 'images/2010/10/25/us/25drugs_337-span/JP-DRUGS-2-articleLarge.jpg', 'xlargewidth': 600, 'xlargeheight': 330}, 'subType': 'xlarge', 'crop_name': 'articleLarge'}, {'rank': 0, 'subtype': 'jumbo', 'caption': None, 'credit': None, 'type': 'image', 'url': 'images/2010/10/25/us/25drugs_337-span/JP-DRUGS-2-jumbo.jpg', 'height': 677, 'width': 1024, 'legacy': {}, 'subType': 'jumbo', 'crop_name': 'jumbo'}, {'rank': 0, 'subtype': 'popup', 'caption': None, 'credit': None, 'type': 'image', 'url': 'images/2010/10/25/us/25drugs_337-span/JP-DRUGS-2-popup.jpg', 'height': 429, 'width': 650, 'legacy': {}, 'subType': 'popup', 'crop_name': 'popup'}, {'rank': 0, 'subtype': 'articleInline', 'caption': None, 'credit': None, 'type': 'image', 'url': 'images/2010/10/25/us/25drugs_337-span/JP-DRUGS-2-articleInline.jpg', 'height': 126, 'width': 190, 'legacy': {}, 'subType': 'articleInline', 'crop_name': 'articleInline'}, {'rank': 0, 'subtype': 'sfSpan', 'caption': None, 'credit': None, 'type': 'image', 'url': 'images/2010/10/25/us/25drugs_337-span/JP-DRUGS-2-sfSpan.jpg', 'height': 250, 'width': 395, 'legacy': {}, 'subType': 'sfSpan', 'crop_name': 'sfSpan'}, {'rank': 0, 'subtype': 'thumbnail', 'caption': None, 'credit': None, 'type': 'image', 'url': 'images/2010/10/25/us/25drugs_337-span/JP-DRUGS-2-thumbStandard.jpg', 'height': 75, 'width': 75, 'legacy': {'thumbnail': 'images/2010/10/25/us/25drugs_ ...

# %%
#It looks like our response category has the meat of data that we'd be interested in, with other subcategories
#clustered beneath it. What are the next level of categories under the response category?


for i in data_list[0]['response']:
    print(i)
# Out:
# docs
# meta

# %%
#What type of data is held in the meta category? 

print(data_list[0]['response']['meta'])
# Out:
# {'hits': 39, 'offset': 0, 'time': 164}

# %%
#What type of data is held in the docs category?

data_list[0]['response']['docs']
# Out:
# [{'_id': 'nyt://article/d163a755-71d8-5fdb-a9e5-55b6560bf2f3',
#   'abstract': 'A review cited a higher risk of bone fracture, heart attack and death with use of narcotic-based drugs.',
#   'byline': {'organization': None,
#    'original': 'By Barry Meier',
#    'person': [{'firstname': 'Barry',
#      'lastname': 'Meier',
#      'middlename': None,
#      'organization': '',
#      'qualifier': None,
#      'rank': 1,
#      'role': 'reported',
#      'title': None}]},
#   'document_type': 'article',
#   'headline': {'content_kicker': None,
#    'kicker': None,
#    'main': 'Narcotic Painkillers May Pose Danger to Elderly Patients, Study Says',
#    'name': None,
#    'print_headline': 'Narcotic Painkillers, Thought Safer for Elderly Patients, May Pose More Risk, Study Says',
#    'seo': None,
#    'sub': None},
#   'keywords': [{'major': 'N',
#     'name': 'subject',
#     'rank': 1,
#     'value': 'ARTHRITIS AND RHEUMATISM'},
#    {'major': 'N', 'name': 'subject', 'rank': 2, 'value': 'Elderly'},
#    {'major': 'N',
#     'name': 'subject',
#     'rank': 3,
#     'value': 'Drugs (Pharmaceuticals)'},
#    {'major': 'N',
#     'name': 'subject',
#     'rank': 4,
#     'value': 'Pain-Relieving Drugs'}],
#   'lead_paragraph': ' Older patients with arthritis who take narcotic-based drugs to relieve pain face a higher risk of bone fracture, heart attack and death when compared to those taking non-narcotic drugs, according to a government-financed study published Monday.',
#   'multimedia': [],
#   'news_desk': 'Business',
#   'print_page': '3',
#   'print_section': 'B',
#   'pub_date': '2010-12-13T20:08:40+0000',
#   'section_name': 'Health',
#   'snippet': 'A review cited a higher risk of bone fracture, heart attack and death with use of narcotic-based drugs.',
#   'source': 'The New York Times',
#   'type_of_material': 'News',
#   'uri': 'nyt://article/d163a755-71d8-5fdb-a9e5-55b6560bf2f3',
#   'web_url': 'https://www.nytimes.com/2010/12/14/health/14drug.html',
#   'word_count': 635},
#  {'_id': 'nyt://article/d0a79639-2036-553e-94f9-6f2693724263',
#   'abstract': 'Workplace testing is drawing complaints from employees who say they should not be fired for taking legal drugs.',
#   'byline': {'organization': None,
#    'original': 'By Katie Zezima and Abby Goodnough',
#    'person': [{'firstname': 'Katie',
#      'lastname': 'Zezima',
#      'middlename': None,
#      'organization': '',
#      'qualifier': None,
#      'rank': 1,
#      'role': 'reported',
#      'title': None},
#     {'firstname': 'Abby',
#      'lastname': 'Goodnough',
#      'middlename': None,
#      'organization': '',
#      'qualifier': None,
#      'rank': 2,
#      'role': 'reported',
#      'title': None}]},
#   'document_type': 'article',
#   'headline': {'content_kicker': None,
#    'kicker': None,
#    'main': 'Drug Testing Poses Quandary for Employers',
#    'name': None,
#    'print_headline': 'Testing for Prescription Drugs Poses Quandary for Employers',
#    'seo': None,
#    'sub': None},
#   'keywords': [{'major': 'N',
#     'name': 'organizations',
#     'rank': 1,
#     'value': 'DURA AUTOMOTIVE SYSTEMS INCORPORATED'},
#    {'major': 'N', 'name': 'subject', 'rank': 2, 'value': 'Tests and Testing'},
#    {'major': 'N',
#     'name': 'subject',
#     'rank': 3,
#     'value': 'Pain-Relieving Drugs'},
#    {'major': 'N',
#     'name': 'subject',
#     'rank': 4,
#     'value': 'ACCIDENTS AND SAFETY'},
#    {'major': 'N',
#     'name': 'subject',
#     'rank': 5,
#     'value': 'Drugs (Pharmaceuticals)'},
#    {'major': 'N',
#     'name': 'subject',
#     'rank': 6,
#     'value': 'Drug Abuse and Traffic'},
#    {'major': 'N', 'name': 'subject', 'rank': 7, 'value': 'Labor and Jobs'}],
#   'lead_paragraph': 'LAWRENCEBURG, Tenn. \x97 The news, delivered in a phone call, left Sue Bates aghast: she was losing her job of 22 years after testing positive for a legally prescribed drug. ',
#   'multimedia': [{'caption': None,
#     'credit': None,
#     'crop_name': 'articleLarge',
#     'height': 330,
#     'legacy': {'xlarge': 'images/2010/10/25/us/25drugs_337-span/JP-DRUGS-2-articleLarge.jpg',
#      'xlargeheight': 330,
#      'xlargewidth': 600},
#     'rank': 0,
#     'subType': 'xlarge',
#     'subtype': 'xlarge',
#     'type': 'image',
#     'url': 'images/2010/10/25/us/25drugs_337-span/JP-DRUGS-2-articleLarge.jpg',
#     'width': 600},
#    {'caption': None,
#     'credit': None,
#     'crop_name': 'jumbo',
#     'height': 677,
#     'legacy': {},
#     'rank': 0,
#     'subType': 'jumbo',
#     'subtype': 'jumbo',
#     'type': 'image',
#     'url': 'images/2010/10/25/us/25drugs_337-span/JP-DRUGS-2-jumbo.jpg',
#     'width': 1024},
#    {'caption': None,
#     'credit': None,
#     'crop_name': 'popup',
#     'height': 429,
#     'legacy': {},
#     'rank': 0,
#     'subType': 'popup',
#     'subtype': 'popup',
#     'type': 'image',
#     'url': 'images/2010/10/25/us/25drugs_337-span/JP-DRUGS-2-popup.jpg',
#     'width': 650},
#    {'caption': None,
#     'credit': None,
#     'crop_name': 'articleInline',
#     'height': 126,
#     'legacy': {},
#     'rank': 0,
#     'subType': 'articleInline',
#     'subtype': 'articleInline',
#     'type': 'image',
#     'url': 'images/2010/10/25/us/25drugs_337-span/JP-DRUGS-2-articleInline.jpg',
#     'width': 190},
#    {'caption': None,
#     'credit': None,
#     'crop_name': 'sfSpan',
#     'height': 250,
#     'legacy': {},
#     'rank': 0,
#     'subType': 'sfSpan',
#     'subtype': 'sfSpan',
#     'type': 'image',
#     'url': 'images/2010/10/25/us/25drugs_337-span/JP-DRUGS-2-sfSpan.jpg',
#     'width': 395},
#    {'caption': None,
#     'credit': None,
#     'crop_name': 'thumbStandard',
#     'height': 75,
#     'legacy': {'thumbnail': 'images/2010/10/25/us/25drugs_337-span/JP-DRUGS-2-thumbStandard.jpg',
#      'thumbnailheight': 75,
#      'thumbnailwidth': 75},
#     'rank': 0,
#     'subType': 'thumbnail',
#     'subtype': 'thumbnail',
#     'type': 'image',
#     'url': 'images/2010/10/25/us/25drugs_337-span/JP-DRUGS-2-thumbStandard.jpg',
#     'width': 75}],
#   'news_desk': 'National',
#   'print_page': '1',
#   'print_section': 'A',
#   'pub_date': '2010-10-24T23:38:15+0000',
#   'section_name': 'U.S.',
#   'snippet': 'Workplace testing is drawing complaints from employees who say they should not be fired for taking legal drugs.',
#   'source': 'The New York Times',
#   'type_of_material': 'News',
#   'uri': 'nyt://article/d0a79639-2036-553e-94f9-6f2693724263',
#   'web_url': 'https://www.nytimes.com/2010/10/25/us/25drugs.html',
#   'word_count': 2294},
#  {'_id': 'nyt://article/32522fc0-ad24-56bc-b2f6-ed832f9b667e',
#   'abstract': 'Drug users are breaking into people’s homes in search of prescription painkillers and other medications.',
#   'byline': {'organization': None,
#    'original': 'By Abby Goodnough',
#    'person': [{'firstname': 'Abby',
#      'lastname': 'Goodnough',
#      'middlename': None,
#      'organization': '',
#      'qualifier': None,
#      'rank': 1,
#      'role': 'reported',
#      'title': None}]},
#   'document_type': 'article',
#   'headline': {'content_kicker': None,
#    'kicker': None,
#    'main': 'A Wave of Addiction and Crime, with the Medicine Cabinet to Blame',
#    'name': None,
#    'print_headline': 'A Wave of Addiction and Crime, With the Medicine Cabinet to Blame',
#    'seo': None,
#    'sub': None},
#   'keywords': [{'major': 'N',
#     'name': 'subject',
#     'rank': 1,
#     'value': 'Drug Abuse and Traffic'},
#    {'major': 'N',
#     'name': 'subject',
#     'rank': 2,
#     'value': 'Drugs (Pharmaceuticals)'},
#    {'major': 'N',
#     'name': 'organizations',
#     'rank': 3,
#     'value': 'Drug Enforcement Administration'},
#    {'major': 'N',
#     'name': 'subject',
#     'rank': 4,
#     'value': 'Pain-Relieving Drugs'}],
#   'lead_paragraph': 'BOSTON \x97 Police departments have collected thousands of handguns through buy-back programs in communities throughout the country. Now they want the contents of your medicine cabinet.',
#   'multimedia': [{'caption': None,
#     'credit': None,
#     'crop_name': 'articleLarge',
#     'height': 330,
#     'legacy': {'xlarge': 'images/2010/09/24/us/24drugs_395-inline/24drugs_395-inline-articleLarge.jpg',
#      'xlargeheight': 330,
#      'xlargewidth': 600},
#     'rank': 0,
#     'subType': 'xlarge',
#     'subtype': 'xlarge',
#     'type': 'image',
#     'url': 'images/2010/09/24/us/24drugs_395-inline/24drugs_395-inline-articleLarge.jpg',
#     'width': 600},
#    {'caption': None,
#     'credit': None,
#     'crop_name': 'jumbo',
#     'height': 760,
#     'legacy': {},
#     'rank': 0,
#     'subType': 'jumbo',
#     'subtype': 'jumbo',
#     'type': 'image',
#     'url': 'images/2010/09/24/us/24drugs_395-inline/24drugs_395-span-jumbo.jpg',
#     'width': 1024},
#    {'caption': None,
#     'credit': None,
#     'crop_name': 'popup',
#     'height': 482,
#     'legacy': {},
#     'rank': 0,
#     'subType': 'popup',
#     'subtype': 'popup',
#     'type': 'image',
#     'url': 'images/2010/09/24/us/24drugs_395-inline/24drugs_395-span-popup.jpg',
#     'width': 650},
#    {'caption': None,
#     'credit': None,
#     'crop_name': 'articleInline',
#     'height': 140,
#     'legacy': {},
#     'rank': 0,
#     'subType': 'articleInline',
#     'subtype': 'articleInline',
#     'type': 'image',
#     'url': 'images/2010/09/24/us/24drugs_395-inline/24drugs_395-span-articleInline.jpg',
#     'width': 190},
#    {'caption': None,
#     'credit': None,
#     'crop_name': 'sfSpan',
#     'height': 270,
#     'legacy': {},
#     'rank': 0,
#     'subType': 'sfSpan',
#     'subtype': 'sfSpan',
#     'type': 'image',
#     'url': 'images/2010/09/24/us/24drugs_395-inline/24drugs_395-span-sfSpan.jpg',
#     'width': 395},
#    {'caption': None,
#     'credit': None,
#     'crop_name': 'thumbStandard',
#     'height': 75,
#     'legacy': {'thumbnail': 'images/2010/09/24/us/24drugs_395-inline/24drugs_395-span-thumbStandard.jpg',
#      'thumbnailheight': 75,
#      'thumbnailwidth': 75},
#     'rank': 0,
#     'subType': 'thumbnail',
#     'subtype': 'thumbnail',
#     'type': 'image',
#     'url': 'images/2010/09/24/us/24drugs_395-inline/24drugs_395-span-thumbStandard.jpg',
#     'width': 75}],
#   'news_desk': 'National',
#   'print_page': '14',
#   'print_section': 'A',
#   'pub_date': '2010-09-24T00:23:07+0000',
#   'section_name': 'U.S.',
#   'snippet': 'Drug users are breaking into people’s homes in search of prescription painkillers and other medications.',
#   'source': 'The New York Times',
#   'type_of_material': 'News',
#   'uri': 'nyt://article/32522fc0-ad24-56bc-b2f6-ed832f9b667e',
#   'web_url': 'https://www.nytimes.com/2010/09/24/us/24drugs.html',
#   'word_count': 1045},
#  {'_id': 'nyt://article/74fd453a-a318-58dc-9d42-db4b6cccca4e',
#   'abstract': 'San Francisco police officers say they are seeing more elderly, sick or disabled people selling their medications on the street.',
#   'byline': {'organization': None,
#    'original': 'By Shoshana Walter',
#    'person': [{'firstname': 'Shoshana',
#      'lastname': 'Walter',
#      'middlename': None,
#      'organization': '',
#      'qualifier': None,
#      'rank': 1,
#      'role': 'reported',
#      'title': None}]},
#   'document_type': 'article',
#   'headline': {'content_kicker': None,
#    'kicker': 'The Bay Citizen',
#    'main': 'Officers See More Sick and Elderly Selling Prescription Drugs',
#    'name': None,
#    'print_headline': 'Officers See More Sick and Elderly Selling Prescription Drugs',
#    'seo': None,
#    'sub': None},
#   'keywords': [{'major': 'N',
#     'name': 'subject',
#     'rank': 1,
#     'value': 'OxyContin (Drug)'},
#    {'major': 'N',
#     'name': 'subject',
#     'rank': 2,
#     'value': 'Pain-Relieving Drugs'},
#    {'major': 'N', 'name': 'subject', 'rank': 3, 'value': 'Elderly'},
#    {'major': 'N',
#     'name': 'subject',
#     'rank': 4,
#     'value': 'Cocaine and Crack Cocaine'},
#    {'major': 'N',
#     'name': 'glocations',
#     'rank': 5,
#     'value': 'San Francisco (Calif)'},
#    {'major': 'N',
#     'name': 'subject',
#     'rank': 6,
#     'value': 'Drug Abuse and Traffic'}],
#   'lead_paragraph': 'In Gregory Watts’s 13 years as a San Francisco police officer, he has arrested countless drug dealers. But only recently did he begin to notice that many of them resembled his grandparents.',
#   'multimedia': [{'caption': None,
#     'credit': None,
#     'crop_name': 'jumbo',
#     'height': 1024,
#     'legacy': {},
#     'rank': 0,
#     'subType': 'jumbo',
#     'subtype': 'jumbo',
#     'type': 'image',
#     'url': 'images/2010/09/19/us/19BCDEALERS/19BCDEALERS-jumbo.jpg',
#     'width': 1024},
#    {'caption': None,
#     'credit': None,
#     'crop_name': 'popup',
#     'height': 650,
#     'legacy': {},
#     'rank': 0,
#     'subType': 'popup',
#     'subtype': 'popup',
#     'type': 'image',
#     'url': 'images/2010/09/19/us/19BCDEALERS/19BCDEALERS-popup.jpg',
#     'width': 650},
#    {'caption': None,
#     'credit': None,
#     'crop_name': 'articleInline',
#     'height': 190,
#     'legacy': {},
#     'rank': 0,
#     'subType': 'articleInline',
#     'subtype': 'articleInline',
#     'type': 'image',
#     'url': 'images/2010/09/19/us/19BCDEALERS/19BCDEALERS-articleInline.jpg',
#     'width': 190}],
#   'news_desk': 'National',
#   'print_page': '35A',
#   'print_section': 'A',
#   'pub_date': '2010-09-18T23:36:47+0000',
#   'section_name': 'U.S.',
#   'snippet': 'San Francisco police officers say they are seeing more elderly, sick or disabled people selling their medications on the street.',
#   'source': 'The New York Times',
#   'type_of_material': 'News',
#   'uri': 'nyt://article/74fd453a-a318-58dc-9d42-db4b6cccca4e',
#   'web_url': 'https://www.nytimes.com/2010/09/19/us/19bcdealers.html',
#   'word_count': 476},
#  {'_id': 'nyt://article/77649ce3-0a58-56fe-8129-fda083e69738',
#   'abstract': 'An expansive mix of medical reportage, history and memoir explores our relationship to pain.',
#   'byline': {'organization': None,
#    'original': 'By Robin Romm',
#    'person': [{'firstname': 'Robin',
#      'lastname': 'Romm',
#      'middlename': None,
#      'organization': '',
#      'qualifier': None,
#      'rank': 1,
#      'role': 'reported',
#      'title': None}]},
#   'document_type': 'article',
#   'headline': {'content_kicker': None,
#    'kicker': None,
#    'main': 'Where It Hurts',
#    'name': None,
#    'print_headline': 'Where It Hurts',
#    'seo': None,
#    'sub': None},
#   'keywords': [{'major': 'N',
#     'name': 'subject',
#     'rank': 1,
#     'value': 'Pain-Relieving Drugs'},
#    {'major': 'N', 'name': 'subject', 'rank': 2, 'value': 'Pain'},
#    {'major': 'N',
#     'name': 'subject',
#     'rank': 3,
#     'value': 'Books and Literature'},
#    {'major': 'N',
#     'name': 'subject',
#     'rank': 4,
#     'value': 'Medicine and Health'},
#    {'major': 'N',
#     'name': 'subject',
#     'rank': 5,
#     'value': 'ANESTHESIA AND ANESTHETICS'},
#    {'major': 'N',
#     'name': 'persons',
#     'rank': 6,
#     'value': 'Thernstrom, Melanie'}],
#   'lead_paragraph': 'A simple understanding of pain would be this: It’s a biological response to injury or disease. Treat the cause and the pain abates. The body, after all, is a relatively efficient machine. But what happens when the wound won’t heal? And what if pain doesn’t stem from injury or disease, but is itself the problem?',
#   'multimedia': [{'caption': None,
#     'credit': None,
#     'crop_name': 'jumbo',
#     'height': 949,
#     'legacy': {},
#     'rank': 0,
#     'subType': 'jumbo',
#     'subtype': 'jumbo',
#     'type': 'image',
#     'url': 'images/2010/08/29/books/review/Romm-t_CA0/Romm-t_CA0-jumbo.jpg',
#     'width': 964},
#    {'caption': None,
#     'credit': None,
#     'crop_name': 'popup',
#     'height': 640,
#     'legacy': {},
#     'rank': 0,
#     'subType': 'popup',
#     'subtype': 'popup',
#     'type': 'image',
#     'url': 'images/2010/08/29/books/review/Romm-t_CA0/Romm-t_CA0-popup.jpg',
#     'width': 650},
#    {'caption': None,
#     'credit': None,
#     'crop_name': 'articleInline',
#     'height': 187,
#     'legacy': {},
#     'rank': 0,
#     'subType': 'articleInline',
#     'subtype': 'articleInline',
#     'type': 'image',
#     'url': 'images/2010/08/29/books/review/Romm-t_CA0/Romm-t_CA0-articleInline.jpg',
#     'width': 190},
#    {'caption': None,
#     'credit': None,
#     'crop_name': 'thumbStandard',
#     'height': 75,
#     'legacy': {'thumbnail': 'images/2010/08/29/books/review/Romm-t_CA0/Romm-t_CA0-thumbStandard.jpg',
#      'thumbnailheight': 75,
#      'thumbnailwidth': 75},
#     'rank': 0,
#     'subType': 'thumbnail',
#     'subtype': 'thumbnail',
#     'type': 'image',
#     'url': 'images/2010/08/29/books/review/Romm-t_CA0/Romm-t_CA0-thumbStandard.jpg',
#     'width': 75}],
#   'news_desk': 'BookReview',
#   'print_page': '12',
#   'print_section': 'BR',
#   'pub_date': '2010-08-26T21:14:01+0000',
#   'section_name': 'Books',
#   'snippet': 'An expansive mix of medical reportage, history and memoir explores our relationship to pain.',
#   'source': 'The New York Times',
#   'subsection_name': 'Book Review',
#   'type_of_material': 'Review',
#   'uri': 'nyt://article/77649ce3-0a58-56fe-8129-fda083e69738',
#   'web_url': 'https://www.nytimes.com/2010/08/29/books/review/Romm-t.html',
#   'word_count': 1180},
#  {'_id': 'nyt://article/794b63ea-9cdc-5384-8d69-ce70b4fad598',
#   'abstract': 'Regulators in Washington State are attempting to stem what some see as the excessive use of prescribed narcotics.',
#   'byline': {'organization': None,
#    'original': 'By Barry Meier',
#    'person': [{'firstname': 'Barry',
#      'lastname': 'Meier',
#      'middlename': None,
#      'organization': '',
#      'qualifier': None,
#      'rank': 1,
#      'role': 'reported',
#      'title': None}]},
#   'document_type': 'article',
#   'headline': {'content_kicker': None,
#    'kicker': None,
#    'main': 'Move to Restrict Pain Killers Puts Onus on Doctors',
#    'name': None,
#    'print_headline': 'When Pain Drugs Hurt',
#    'seo': None,
#    'sub': None},
#   'keywords': [{'major': 'N',
#     'name': 'subject',
#     'rank': 1,
#     'value': 'Doctors'},
#    {'major': 'N',
#     'name': 'glocations',
#     'rank': 2,
#     'value': 'Washington (State)'},
#    {'major': 'N',
#     'name': 'subject',
#     'rank': 3,
#     'value': 'Drugs (Pharmaceuticals)'},
#    {'major': 'N',
#     'name': 'subject',
#     'rank': 4,
#     'value': 'Regulation and Deregulation of Industry'},
#    {'major': 'N',
#     'name': 'subject',
#     'rank': 5,
#     'value': 'Pain-Relieving Drugs'}],
#   'lead_paragraph': 'In an unusual move, a state government is developing regulations meant to stop doctors from prescribing higher doses of powerful \x97 and often dangerous \x97 pain killers for patients who are not benefiting from them.',
#   'multimedia': [{'caption': None,
#     'credit': None,
#     'crop_name': 'articleLarge',
#     'height': 350,
#     'legacy': {'xlarge': 'images/2010/07/29/business/29pain1/29pain1-articleLarge.jpg',
#      'xlargeheight': 350,
#      'xlargewidth': 600},
#     'rank': 0,
#     'subType': 'xlarge',
#     'subtype': 'xlarge',
#     'type': 'image',
#     'url': 'images/2010/07/29/business/29pain1/29pain1-articleLarge.jpg',
#     'width': 600},
#    {'caption': None,
#     'credit': None,
#     'crop_name': 'jumbo',
#     'height': 683,
#     'legacy': {},
#     'rank': 0,
#     'subType': 'jumbo',
#     'subtype': 'jumbo',
#     'type': 'image',
#     'url': 'images/2010/07/29/business/29pain1/29pain1-jumbo.jpg',
#     'width': 1024},
#    {'caption': None,
#     'credit': None,
#     'crop_name': 'popup',
#     'height': 433,
#     'legacy': {},
#     'rank': 0,
#     'subType': 'popup',
#     'subtype': 'popup',
#     'type': 'image',
#     'url': 'images/2010/07/29/business/29pain1/29pain1-popup.jpg',
#     'width': 650},
#    {'caption': None,
#     'credit': None,
#     'crop_name': 'articleInline',
#     'height': 127,
#     'legacy': {},
#     'rank': 0,
#     'subType': 'articleInline',
#     'subtype': 'articleInline',
#     'type': 'image',
#     'url': 'images/2010/07/29/business/29pain1/29pain1-articleInline.jpg',
#     'width': 190},
#    {'caption': None,
#     'credit': None,
#     'crop_name': 'sfSpan',
#     'height': 250,
#     'legacy': {},
#     'rank': 0,
#     'subType': 'sfSpan',
#     'subtype': 'sfSpan',
#     'type': 'image',
#     'url': 'images/2010/07/29/business/29pain1/29pain1-sfSpan.jpg',
#     'width': 395},
#    {'caption': None,
#     'credit': None,
#     'crop_name': 'thumbStandard',
#     'height': 75,
#     'legacy': {'thumbnail': 'images/2010/07/29/business/29pain1/29pain1-thumbStandard.jpg',
#      'thumbnailheight': 75,
#      'thumbnailwidth': 75},
#     'rank': 0,
#     'subType': 'thumbnail',
#     'subtype': 'thumbnail',
#     'type': 'image',
#     'url': 'images/2010/07/29/business/29pain1/29pain1-thumbStandard.jpg',
#     'width': 75}],
#   'news_desk': 'Business',
#   'print_page': '1',
#   'print_section': 'B',
#   'pub_date': '2010-07-28T16:23:30+0000',
#   'section_name': 'Business Day',
#   'snippet': 'Regulators in Washington State are attempting to stem what some see as the excessive use of prescribed narcotics.',
#   'source': 'The New York Times',
#   'type_of_material': 'News',
#   'uri': 'nyt://article/794b63ea-9cdc-5384-8d69-ce70b4fad598',
#   'web_url': 'https://www.nytimes.com/2010/07/29/business/29pain.html',
#   'word_count': 1108},
#  {'_id': 'nyt://article/94df1e7d-54f6-5dcc-abd1-44971feb5d32',
#   'abstract': 'Mr. Lotsof’s belief that ibogaine could cure addiction to heroin persuaded the F.D.A. to approve a clinical trial, but the substance remains banned in the United States.',
#   'byline': {'organization': None,
#    'original': 'By Dennis Hevesi',
#    'person': [{'firstname': 'Dennis',
#      'lastname': 'Hevesi',
#      'middlename': None,
#      'organization': '',
#      'qualifier': None,
#      'rank': 1,
#      'role': 'reported',
#      'title': None}]},
#   'document_type': 'article',
#   'headline': {'content_kicker': None,
#    'kicker': None,
#    'main': 'Howard Lotsof Dies at 66; Saw Drug Cure in a Plant',
#    'name': None,
#    'print_headline': 'Howard Lotsof, 66; Saw Drug Cure in a Plant\n',
#    'seo': None,
#    'sub': None},
#   'keywords': [{'major': 'N',
#     'name': 'subject',
#     'rank': 1,
#     'value': 'Medicine and Health'},
#    {'major': 'N',
#     'name': 'subject',
#     'rank': 2,
#     'value': 'Drugs (Pharmaceuticals)'},
#    {'major': 'N',
#     'name': 'subject',
#     'rank': 3,
#     'value': 'Deaths (Obituaries)'}],
#   'lead_paragraph': 'Howard Lotsof was 19, addicted to heroin and searching for a new high in 1962 when he swallowed a bitter-tasting white powder taken from an exotic West African shrub. ',
#   'multimedia': [{'caption': None,
#     'credit': None,
#     'crop_name': 'popup',
#     'height': 450,
#     'legacy': {},
#     'rank': 0,
#     'subType': 'popup',
#     'subtype': 'popup',
#     'type': 'image',
#     'url': 'images/2010/02/17/us/17lotsofimg/17lotsofimg-popup.jpg',
#     'width': 303},
#    {'caption': None,
#     'credit': None,
#     'crop_name': 'articleInline',
#     'height': 266,
#     'legacy': {},
#     'rank': 0,
#     'subType': 'articleInline',
#     'subtype': 'articleInline',
#     'type': 'image',
#     'url': 'images/2010/02/17/us/17lotsofimg/17lotsofimg-articleInline.jpg',
#     'width': 190},
#    {'caption': None,
#     'credit': None,
#     'crop_name': 'thumbStandard',
#     'height': 75,
#     'legacy': {'thumbnail': 'images/2010/02/17/us/17lotsofimg/17lotsofimg-thumbStandard.jpg',
#      'thumbnailheight': 75,
#      'thumbnailwidth': 75},
#     'rank': 0,
#     'subType': 'thumbnail',
#     'subtype': 'thumbnail',
#     'type': 'image',
#     'url': 'images/2010/02/17/us/17lotsofimg/17lotsofimg-thumbStandard.jpg',
#     'width': 75}],
#   'news_desk': 'National',
#   'print_page': '25',
#   'print_section': 'A',
#   'pub_date': '2010-02-17T06:05:45+0000',
#   'section_name': 'U.S.',
#   'snippet': 'Mr. Lotsof’s belief that ibogaine could cure addiction to heroin persuaded the F.D.A. to approve a clinical trial, but the substance remains banned in the United States.',
#   'source': 'The New York Times',
#   'type_of_material': 'Obituary (Obit)',
#   'uri': 'nyt://article/94df1e7d-54f6-5dcc-abd1-44971feb5d32',
#   'web_url': 'https://www.nytimes.com/2010/02/17/us/17lotsof.html',
#   'word_count': 767},
#  {'_id': 'nyt://article/27343e57-ab0c-5d24-8493-18a5480309a9',
#   'abstract': 'Emergency room visits for nonmedical use of prescription and over-the-counter drugs doubled during a recent five-year period.',
#   'byline': {'organization': None,
#    'original': 'By Roni Caryn Rabin',
#    'person': [{'firstname': 'Roni',
#      'lastname': 'Rabin',
#      'middlename': 'Caryn',
#      'organization': '',
#      'qualifier': None,
#      'rank': 1,
#      'role': 'reported',
#      'title': None}]},
#   'document_type': 'article',
#   'headline': {'content_kicker': None,
#    'kicker': 'Vital Signs',
#    'main': 'Hazards: Emergencies Over Legal Drugs Increase',
#    'name': None,
#    'print_headline': 'HAZARDS: Sharp Rise in Abuse of Legal Drugs',
#    'seo': None,
#    'sub': None},
#   'keywords': [{'major': 'N', 'name': 'subject', 'rank': 1, 'value': 'Pain'},
#    {'major': 'N',
#     'name': 'subject',
#     'rank': 2,
#     'value': 'Drug Abuse and Traffic'},
#    {'major': 'N',
#     'name': 'subject',
#     'rank': 3,
#     'value': 'Medicine and Health'},
#    {'major': 'N',
#     'name': 'subject',
#     'rank': 4,
#     'value': 'Emergency Medical Treatment'}],
#   'lead_paragraph': 'Emergency room visits for nonmedical use of prescription and over-the-counter drugs doubled during a recent five-year-period, the Centers for Disease Control and Prevention are reporting. ',
#   'multimedia': [],
#   'news_desk': 'Science',
#   'print_page': '6',
#   'print_section': 'D',
#   'pub_date': '2010-06-21T19:06:49+0000',
#   'section_name': 'Health',
#   'snippet': 'Emergency room visits for nonmedical use of prescription and over-the-counter drugs doubled during a recent five-year period.',
#   'source': 'The New York Times',
#   'subsection_name': 'Research',
#   'type_of_material': 'News',
#   'uri': 'nyt://article/27343e57-ab0c-5d24-8493-18a5480309a9',
#   'web_url': 'https://www.nytimes.com/2010/06/22/health/research/22haza.html',
#   'word_count': 161},
#  {'_id': 'nyt://interactive/6a38ce48-ccab-540d-952b-db5e7b5275de',
#   'abstract': 'Mysterious pain, doubting doctors, depression, fatigue and brain fog — six people speak about living with fibromyalgia.',
#   'byline': {'organization': None, 'original': None, 'person': []},
#   'document_type': 'multimedia',
#   'headline': {'content_kicker': None,
#    'kicker': None,
#    'main': 'Patient Voices: Fibromyalgia',
#    'name': None,
#    'print_headline': None,
#    'seo': None,
#    'sub': None},
#   'keywords': [{'major': 'N',
#     'name': 'subject',
#     'rank': 1,
#     'value': 'Fibromyalgia'},
#    {'major': 'N',
#     'name': 'subject',
#     'rank': 2,
#     'value': 'Medicine and Health'},
#    {'major': 'N', 'name': 'subject', 'rank': 3, 'value': 'Pain'},
#    {'major': 'N',
#     'name': 'subject',
#     'rank': 4,
#     'value': 'Pain-Relieving Drugs'}],
#   'lead_paragraph': 'Mysterious pain, doubting doctors, depression, fatigue and brain fog — six people speak about living with fibromyalgia.',
#   'multimedia': [{'caption': None,
#     'credit': None,
#     'crop_name': 'thumbWide',
#     'height': 126,
#     'legacy': {'wide': 'images/2010/03/04/science/fibromyalgia_promo/fibromyalgia_promo-thumbWide.jpg',
#      'wideheight': 126,
#      'widewidth': 190},
#     'rank': 0,
#     'subType': 'wide',
#     'subtype': 'wide',
#     'type': 'image',
#     'url': 'images/2010/03/04/science/fibromyalgia_promo/fibromyalgia_promo-thumbWide.jpg',
#     'width': 190},
#    {'caption': None,
#     'credit': None,
#     'crop_name': 'blog480',
#     'height': 319,
#     'legacy': {},
#     'rank': 0,
#     'subType': 'blog480',
#     'subtype': 'blog480',
#     'type': 'image',
#     'url': 'images/2010/03/04/science/fibromyalgia_promo/fibromyalgia_promo-blogSpan.jpg',
#     'width': 480},
#    {'caption': None,
#     'credit': None,
#     'crop_name': 'popup',
#     'height': 250,
#     'legacy': {},
#     'rank': 0,
#     'subType': 'popup',
#     'subtype': 'popup',
#     'type': 'image',
#     'url': 'images/2010/03/04/science/fibromyalgia_promo/fibromyalgia_promo-sfSpan.jpg',
#     'width': 395},
#    {'caption': None,
#     'credit': None,
#     'crop_name': 'sfSpan',
#     'height': 250,
#     'legacy': {},
#     'rank': 0,
#     'subType': 'sfSpan',
#     'subtype': 'sfSpan',
#     'type': 'image',
#     'url': 'images/2010/03/04/science/fibromyalgia_promo/fibromyalgia_promo-sfSpan.jpg',
#     'width': 395},
#    {'caption': None,
#     'credit': None,
#     'crop_name': 'thumbStandard',
#     'height': 75,
#     'legacy': {'thumbnail': 'images/2010/03/04/science/fibromyalgia_promo/fibromyalgia_promo-thumbStandard.jpg',
#      'thumbnailheight': 75,
#      'thumbnailwidth': 75},
#     'rank': 0,
#     'subType': 'thumbnail',
#     'subtype': 'thumbnail',
#     'type': 'image',
#     'url': 'images/2010/03/04/science/fibromyalgia_promo/fibromyalgia_promo-thumbStandard.jpg',
#     'width': 75}],
#   'news_desk': 'Health',
#   'pub_date': '2010-03-03T17:24:34+0000',
#   'section_name': 'Health',
#   'snippet': 'Mysterious pain, doubting doctors, depression, fatigue and brain fog — six people speak about living with fibromyalgia.',
#   'source': 'The New York Times',
#   'subsection_name': 'Health Guide',
#   'type_of_material': 'Interactive Feature',
#   'uri': 'nyt://interactive/6a38ce48-ccab-540d-952b-db5e7b5275de',
#   'web_url': 'https://www.nytimes.com/interactive/2010/03/04/health/healthguide/TE_fibromyalgia.html',
#   'word_count': 0},
#  {'_id': 'nyt://article/f26da0b6-17cd-5274-8f0d-2768394ecf8f',
#   'abstract': 'The pain killer and related drugs can cause fatal heart rhythms.',
#   'byline': {'organization': None,
#    'original': 'By Duff Wilson',
#    'person': [{'firstname': 'Duff',
#      'lastname': 'Wilson',
#      'middlename': None,
#      'organization': '',
#      'qualifier': None,
#      'rank': 1,
#      'role': 'reported',
#      'title': None}]},
#   'document_type': 'article',
#   'headline': {'content_kicker': None,
#    'kicker': 'Prescriptions',
#    'main': 'Darvon Pulled From Market by F.D.A.',
#    'name': None,
#    'print_headline': None,
#    'seo': None,
#    'sub': None},
#   'keywords': [],
#   'lead_paragraph': 'The painkilling drug propoxyphene, sold under the Darvon and Darvocet brands and used by about 10 million Americans last year, will be removed from the market because of serious heart risks, the Food and Drug Administration said on Friday.',
#   'multimedia': [],
#   'news_desk': '',
#   'pub_date': '2010-11-19T19:03:09+0000',
#   'section_name': 'Health',
#   'snippet': 'The pain killer and related drugs can cause fatal heart rhythms.',
#   'source': 'The New York Times',
#   'uri': 'nyt://article/f26da0b6-17cd-5274-8f0d-2768394ecf8f',
#   'web_url': 'https://prescriptions.blogs.nytimes.com/2010/11/19/darvon-pulled-from-market-by-f-d-a/',
#   'word_count': 732}]

# %% [markdown]
# ## Naming Our Articles
#
# Now that we've found out where our article text and metadata is stored, how do we go about organizing and saving this information in an ordered and structured way?
#
# We can start by naming each of the articles for easier recall access later. We can do this by taking the last name of the author and the yer the article was published and using this as the filename to save the article as.

# %%
#We pull out the last name by going into the docs category of the repsonse, calling the first article in 
#our data(the [0]), going into the byline category, further into the person category, and selecting the 
#lastname category, giving us just the last name of the author of this first article.

data_list[0]['response']['docs'][0]['byline']['person'][0]['lastname']
# Out:
# 'Meier'

# %%
#We pull out the year publsihed categry in a very similar way, going into the docs category of the repsonse, 
#calling the first article in our data(the [0]), calling the pub_date category and taking only the first 4 
#characters of the pub_date leaving us with just the 4-digit year of publication. 

data_list[0]['response']['docs'][0]['pub_date'][0:4]
# Out:
# '2010'

# %%
#The above was an exmaple of how we do this for one article. We want to automate the process so we don't have to do it
#manually for each article in our data. This code automates the process and makes a list of these article names as it
#goes through our data pulling out the info above, as well as a sepearte list with the years each article was published.

article_name = list()
year = list()

data_list_iter = range(len(data_list))

for d in data_list_iter:
    article_iter = range((len(data_list[d]['response']['docs'])))

    for a in article_iter:
        try:
            last_name =  str(data_list[d]['response']['docs'][a]['byline']['person'][0]['lastname'])
        except:
            last_name = 'no_last_name_'+str(d)+'_'+str(a)
            
        date = data_list[d]['response']['docs'][a]['pub_date'][0:4]
        year.append(int(date))
        name = last_name+'_'+date
        article_name.append(name)

# %%
#Here then we see the content of the list

article_name
# Out:
# ['Meier_2010',
#  'Zezima_2010',
#  'Goodnough_2010',
#  'Walter_2010',
#  'Romm_2010',
#  'Meier_2010',
#  'Hevesi_2010',
#  'Rabin_2010',
#  'no_last_name_0_8_2010',
#  'Wilson_2010',
#  'Bakalar_2011',
#  'Aschwanden_2011',
#  'Jackson_2011',
#  'Belson_2011',
#  'Branch_2011',
#  'Branch_2011',
#  'Bakalar_2011',
#  'Kaplan_2011',
#  'Wilson_2011',
#  'Szalavitz_2011',
#  'Buettner_2012',
#  'Meier_2012',
#  'Pollack_2012',
#  'Grady_2012',
#  'Christopher_2012',
#  'Chen_2012',
#  'Meier_2012',
#  'Hartocollis_2012',
#  'Cave_2012',
#  'Bakalar_2012',
#  'Sontag_2013',
#  'Meier_2013',
#  'Meier_2013',
#  'no_last_name_3_3_2013',
#  'Meier_2013',
#  'Meier_2013',
#  'Bakalar_2013',
#  'Bakalar_2013',
#  'no_last_name_3_8_2013',
#  'Tavernise_2013',
#  'Frakt_2014',
#  'no_last_name_4_1_2014',
#  'Bakalar_2014',
#  'Miller_2014',
#  'McKinley_2014',
#  'Thomas_2014',
#  'Goodman_2014',
#  'Thomas_2014',
#  'Tavernise_2014',
#  'Rabin_2014',
#  'Schwarz_2015',
#  'Friedrichsdorf_2015',
#  'Bakalar_2015',
#  'Brody_2015',
#  'Friedman_2015',
#  'TIEFENTHÄLER_2015',
#  'Harris_2015',
#  'Schwarz_2015',
#  'Louis_2015',
#  'McNeil_2015',
#  'Bakalar_2016',
#  'Louis_2016',
#  'Deutsch_2016',
#  'Catsoulis_2016',
#  'no_last_name_6_4_2016',
#  'Bakalar_2016',
#  'Bakalar_2016',
#  'Seelye_2016',
#  'Goldman_2016',
#  'Thomas_2016',
#  'Lachman_2017',
#  'Hoffman_2017',
#  'Katz_2017',
#  'Kaplan_2017',
#  'no_last_name_7_4_2017',
#  'Frakt_2017',
#  'Smith_2017',
#  'Corkery_2017',
#  'Bakalar_2017',
#  'McNeil_2017',
#  'Meier_2018',
#  'Sinha_2018',
#  'Harlan_2018',
#  'Zuger_2018',
#  'no_last_name_8_4_2018',
#  'Smith_2018',
#  'no_last_name_8_6_2018',
#  'None_2018',
#  'Goodnough_2018',
#  'Symonds_2018',
#  'Goodnough_2019',
#  'Chokshi_2019',
#  'Wagner_2019',
#  'Hoffman_2019',
#  'Barry_2019',
#  'Levin_2019',
#  'Roose_2019',
#  'Waldstein_2019',
#  'Levin_2019',
#  'Goodnough_2019']

# %%
#Let's give this list more order and present it as a table so we can start seeing which articles are in our data along
#with what year they were published. We will be adding more columns and information to this table as we go, including
#the text data we are ultimately interested in.

text_df = pandas.DataFrame(article_name, columns = ["name"])

# %%
text_df['year']=year

# %%
text_df
# Out:
#                      name  year
# 0              Meier_2010  2010
# 1             Zezima_2010  2010
# 2          Goodnough_2010  2010
# 3             Walter_2010  2010
# 4               Romm_2010  2010
# 5              Meier_2010  2010
# 6             Hevesi_2010  2010
# 7              Rabin_2010  2010
# 8   no_last_name_0_8_2010  2010
# 9             Wilson_2010  2010
# 10           Bakalar_2011  2011
# 11        Aschwanden_2011  2011
# 12           Jackson_2011  2011
# 13            Belson_2011  2011
# 14            Branch_2011  2011
# 15            Branch_2011  2011
# 16           Bakalar_2011  2011
# 17            Kaplan_2011  2011
# 18            Wilson_2011  2011
# 19         Szalavitz_2011  2011
# 20          Buettner_2012  2012
# 21             Meier_2012  2012
# 22           Pollack_2012  2012
# 23             Grady_2012  2012
# 24       Christopher_2012  2012
# 25              Chen_2012  2012
# 26             Meier_2012  2012
# 27       Hartocollis_2012  2012
# 28              Cave_2012  2012
# 29           Bakalar_2012  2012
# ..                    ...   ...
# 70           Lachman_2017  2017
# 71           Hoffman_2017  2017
# 72              Katz_2017  2017
# 73            Kaplan_2017  2017
# 74  no_last_name_7_4_2017  2017
# 75             Frakt_2017  2017
# 76             Smith_2017  2017
# 77           Corkery_2017  2017
# 78           Bakalar_2017  2017
# 79            McNeil_2017  2017
# 80             Meier_2018  2018
# 81             Sinha_2018  2018
# 82            Harlan_2018  2018
# 83             Zuger_2018  2018
# 84  no_last_name_8_4_2018  2018
# 85             Smith_2018  2018
# 86  no_last_name_8_6_2018  2018
# 87              None_2018  2018
# 88         Goodnough_2018  2018
# 89           Symonds_2018  2018
# 90         Goodnough_2019  2019
# 91           Chokshi_2019  2019
# 92            Wagner_2019  2019
# 93           Hoffman_2019  2019
# 94             Barry_2019  2019
# 95             Levin_2019  2019
# 96             Roose_2019  2019
# 97         Waldstein_2019  2019
# 98             Levin_2019  2019
# 99         Goodnough_2019  2019
#
# [100 rows x 2 columns]

# %% [markdown]
# ## What Keywords are Used to Label and Describe the Articles Present?
#
# So thus far, we have been able to start parsing through our json file datat to see what it holds, and have begun the process of structuring our data by article to help us progress in our research, starting to build a dataset from raw
# and unstructured data.
#
# What else can we find out about each article?
#
# We saw above there was a keyword field that listed how the NYTimes tagged and categorzied this story for content and search. What keywords were used for each article?

# %%
#Here, we want to look at which keywords were used for article 1 in our data. If we just pull the keywords field
#then we get our information, though it is still kind of messy.

for i in data_list[0]['response']['docs'][0]['keywords']:
    print(i)
# Out:
# {'name': 'subject', 'value': 'ARTHRITIS AND RHEUMATISM', 'rank': 1, 'major': 'N'}
# {'name': 'subject', 'value': 'Elderly', 'rank': 2, 'major': 'N'}
# {'name': 'subject', 'value': 'Drugs (Pharmaceuticals)', 'rank': 3, 'major': 'N'}
# {'name': 'subject', 'value': 'Pain-Relieving Drugs', 'rank': 4, 'major': 'N'}

# %%
#We dive deeper into this output and pull just the first keyword, telling us it's rank of use for this article.

data_list[0]['response']['docs'][0]['keywords'][0]
# Out:
# {'major': 'N',
#  'name': 'subject',
#  'rank': 1,
#  'value': 'ARTHRITIS AND RHEUMATISM'}

# %%
#If we just want the keyword, to put in a column in our article table, then we pull the value field, leaving us with 
#just "Arthritis and Rheumatism

data_list[0]['response']['docs'][0]['keywords'][0]['value']
# Out:
# 'ARTHRITIS AND RHEUMATISM'

# %% [markdown]
# ### What Keywords are Represented in Our 100 Articles?
#
# We can then make a list of all the keywords use for each article, automating the process we did above, and pulling each keyword for each article in our list, as well as a count of how many keywords are used in each article.

# %%
kw_by_doc = list()
number_of_kw = list()

data_list_iter = range(len(data_list))

for d in data_list_iter:
    article_iter = range((len(data_list[d]['response']['docs'])))

    for a in article_iter:
        doc = data_list[d]['response']['docs'][a]
        keyw_iter = range(len(doc['keywords']))
        keywords = list()
        for k in keyw_iter:
            keywords.append(doc['keywords'][k]['value'])
            
        print("article #",a)
        print(keywords)
        print("Number of Keywords:",len(keywords))
        num_kw = len(keywords)
        number_of_kw.append(num_kw)
        kw_by_doc.append(keywords)
# Out:
# article # 0
# ['ARTHRITIS AND RHEUMATISM', 'Elderly', 'Drugs (Pharmaceuticals)', 'Pain-Relieving Drugs']
# Number of Keywords: 4
# article # 1
# ['DURA AUTOMOTIVE SYSTEMS INCORPORATED', 'Tests and Testing', 'Pain-Relieving Drugs', 'ACCIDENTS AND SAFETY', 'Drugs (Pharmaceuticals)', 'Drug Abuse and Traffic', 'Labor and Jobs']
# Number of Keywords: 7
# article # 2
# ['Drug Abuse and Traffic', 'Drugs (Pharmaceuticals)', 'Drug Enforcement Administration', 'Pain-Relieving Drugs']
# Number of Keywords: 4
# article # 3
# ['OxyContin (Drug)', 'Pain-Relieving Drugs', 'Elderly', 'Cocaine and Crack Cocaine', 'San Francisco (Calif)', 'Drug Abuse and Traffic']
# Number of Keywords: 6
# article # 4
# ['Pain-Relieving Drugs', 'Pain', 'Books and Literature', 'Medicine and Health', 'ANESTHESIA AND ANESTHETICS', 'Thernstrom, Melanie']
# Number of Keywords: 6
# article # 5
# ['Doctors', 'Washington (State)', 'Drugs (Pharmaceuticals)', 'Regulation and Deregulation of Industry', 'Pain-Relieving Drugs']
# Number of Keywords: 5
# article # 6
# ['Medicine and Health', 'Drugs (Pharmaceuticals)', 'Deaths (Obituaries)']
# Number of Keywords: 3
# article # 7
# ['Pain', 'Drug Abuse and Traffic', 'Medicine and Health', 'Emergency Medical Treatment']
# Number of Keywords: 4
# article # 8
# ['Fibromyalgia', 'Medicine and Health', 'Pain', 'Pain-Relieving Drugs']
# Number of Keywords: 4
# article # 9
# []
# Number of Keywords: 0
# article # 0
# ['Automobiles', 'Poisoning and Poisons', 'Deaths (Fatalities)', 'Drugs (Pharmaceuticals)', 'Pain-Relieving Drugs', 'National Center for Health Statistics', 'Statistics', 'Traffic Accidents and Safety']
# Number of Keywords: 8
# article # 1
# ['Aspirin', 'Pain-Relieving Drugs', 'Asthma', 'Medicine and Health', 'Research', 'Children and Childhood']
# Number of Keywords: 6
# article # 2
# ['Pain-Relieving Drugs', 'Sports Injuries', 'Football', 'Medicine and Health', 'National Football League', 'Denver Broncos']
# Number of Keywords: 6
# article # 3
# ['Concussions', 'Pain-Relieving Drugs', 'Sports Injuries', 'Football', 'Pathon, Jerome', 'Horn, Joe', 'National Football League', 'Suits and Litigation', 'Joyce, Matt']
# Number of Keywords: 9
# article # 4
# ['Series', 'Fedoruk, Todd', 'Hockey, Ice', 'Boogaard, Derek', 'Concussions', 'Pain-Relieving Drugs', 'Sports Injuries', 'Canada', 'National Hockey League', 'Laraque, Georges', 'Minnesota Wild']
# Number of Keywords: 11
# article # 5
# ['Series', 'Hockey, Ice', 'Boogaard, Derek', 'National Hockey League', 'Pain-Relieving Drugs', 'ALCOHOL ABUSE', 'Sports Injuries', 'Drug Abuse and Traffic', 'Canada', 'New York Rangers', 'Concussions', 'Minnesota Wild']
# Number of Keywords: 12
# article # 6
# ['Hospitals', 'Elderly', 'Medicine and Health', 'Emergency Medical Treatment', 'Pain-Relieving Drugs']
# Number of Keywords: 5
# article # 7
# ['Pain-Relieving Drugs', 'Drugs (Pharmaceuticals)', 'New York City', 'New York City Health and Hospitals Corp', 'Robberies and Thefts', 'Hospitals', 'Organized Crime']
# Number of Keywords: 7
# article # 8
# ['Crime and Criminals', 'Pain-Relieving Drugs', 'Decisions and Verdicts', 'September 11 (2001)', 'Teeth and Dentistry', 'Attention Deficit Hyperactivity Disorder']
# Number of Keywords: 6
# article # 9
# ['Drug Abuse and Traffic', 'Drugs (Pharmaceuticals)', 'Naloxone (Drug)', 'Pain', 'Pain-Relieving Drugs', 'Food and Drug Administration', 'National Institute on Drug Abuse']
# Number of Keywords: 7
# article # 0
# ['Pain-Relieving Drugs', 'Drugs (Pharmaceuticals)', 'Flushing (NYC)', 'Laffer, David S', 'Doctors', 'Li, Stan Xuhui', 'Murders and Attempted Murders']
# Number of Keywords: 7
# article # 1
# ['Drugstores', 'Pain-Relieving Drugs', 'Drugs (Pharmaceuticals)', 'AMERISOURCEBERGEN CORP', 'Cardinal Health Inc', 'Drug Abuse and Traffic', 'Drug Enforcement Administration']
# Number of Keywords: 7
# article # 2
# ['Steroids', 'Drugs (Pharmaceuticals)', 'Meningitis', 'Pain-Relieving Drugs']
# Number of Keywords: 4
# article # 3
# ['New England Compounding Center', 'Factories and Manufacturing', 'Deaths (Fatalities)', 'Drugs (Pharmaceuticals)', 'Meningitis', 'Steroids', 'Pain-Relieving Drugs', 'Health Insurance and Managed Care', 'Food and Drug Administration']
# Number of Keywords: 9
# article # 4
# ['Addiction (Psychology)', 'Drug Abuse and Traffic', 'Pain-Relieving Drugs']
# Number of Keywords: 3
# article # 5
# ['Cancer', 'Doctors', 'Pain', 'Pain-Relieving Drugs']
# Number of Keywords: 4
# article # 6
# ['Regulation and Deregulation of Industry', 'Pain-Relieving Drugs', 'Drugs (Pharmaceuticals)', 'Drug Abuse and Traffic', 'Labeling and Labels', 'Food and Drug Administration']
# Number of Keywords: 6
# article # 7
# ['Drug Abuse and Traffic', 'Drugs (Pharmaceuticals)', 'OxyContin (Drug)', 'Pain-Relieving Drugs', 'FARLEY, THOMAS', 'Schneiderman, Eric T']
# Number of Keywords: 6
# article # 8
# ['Cocaine and Crack Cocaine', 'Heroin', 'Pain-Relieving Drugs', 'United States', 'Drugs (Pharmaceuticals)', 'Mexico', 'Drug Abuse and Traffic', 'Drug Enforcement Administration']
# Number of Keywords: 8
# article # 9
# ['Drugs (Pharmaceuticals)', 'Pain-Relieving Drugs']
# Number of Keywords: 2
# article # 0
# ['Sontag, Deborah', 'Buprenorphine (Drug)', 'Addiction (Psychology)', 'Drug Abuse and Traffic', 'Therapy and Rehabilitation', 'Pain-Relieving Drugs', 'Clark, Allan W', 'Smith, Todd', 'Sullivan, Carl R III', 'Series']
# Number of Keywords: 10
# article # 1
# ['Pain-Relieving Drugs', 'Meier, Barry', 'Drug Abuse and Traffic', 'Addiction (Psychology)', 'ALKERMES INC', 'Elan Corporation PLC', 'Food and Drug Administration', 'Conflicts of Interest']
# Number of Keywords: 8
# article # 2
# ['Meier, Barry', 'Pain-Relieving Drugs', 'Suits and Litigation (Civil)', 'ADVERTISING AND MARKETING', 'Drug Abuse and Traffic', 'Subpoenas', 'Chicago (Ill)', 'Cook County (Ill)', 'Janssen Pharmaceutica', 'Purdue Pharma', 'Endo Pharmaceuticals Inc']
# Number of Keywords: 11
# article # 3
# ['Food and Drug Administration', 'Pain-Relieving Drugs', 'Drug Abuse and Traffic', 'Regulation and Deregulation of Industry', 'Editorials']
# Number of Keywords: 5
# article # 4
# ['Meier, Barry', 'Drug Abuse and Traffic', 'Lipton, Eric', 'Pain-Relieving Drugs', 'Food and Drug Administration', 'Manchin, Joe III', 'Upton, Fred', 'United States Politics and Government', 'Senate', 'House of Representatives']
# Number of Keywords: 10
# article # 5
# ['Meier, Barry', 'Drugs (Pharmaceuticals)', 'Pain-Relieving Drugs', 'Food and Drug Administration', 'Drug Abuse and Traffic', 'Regulation and Deregulation of Industry', 'Woodcock, Janet']
# Number of Keywords: 7
# article # 6
# ['Blacks', 'Children and Childhood', 'Emergency Medical Treatment', 'Hispanic-Americans', 'Hospitals', 'Minorities', 'Pain-Relieving Drugs', 'Race and Ethnicity']
# Number of Keywords: 8
# article # 7
# ['ANESTHESIA AND ANESTHETICS', 'Back (Human Body Part)', 'Pain', 'Pain-Relieving Drugs', 'Steroids']
# Number of Keywords: 5
# article # 8
# ['Pain-Relieving Drugs', 'Labeling and Labels', 'Drug Abuse and Traffic', 'Physicians for Responsible Opioid Prescribing', 'Food and Drug Administration', 'Editorials']
# Number of Keywords: 6
# article # 9
# ['Tavernise, Sabrina', 'Food and Drug Administration', 'Drug Abuse and Traffic', 'Drugs (Pharmaceuticals)', 'Pain-Relieving Drugs', 'Labeling and Labels', 'Physicians for Responsible Opioid Prescribing', 'OxyContin (Drug)']
# Number of Keywords: 8
# article # 0
# ['Drug Abuse and Traffic', 'Pain-Relieving Drugs', 'Drugs (Pharmaceuticals)', 'Buprenorphine (Drug)', 'Pain', 'Food and Drug Administration', 'Regulation and Deregulation of Industry']
# Number of Keywords: 7
# article # 1
# ['United States', 'Drug Abuse and Traffic', 'Pain-Relieving Drugs', 'Pain']
# Number of Keywords: 4
# article # 2
# ['Aspirin', 'Pain-Relieving Drugs', 'Skin Cancer', 'Olsen, Catherine M', 'Journal of Investigative Dermatology', 'QIMR Berghofer Medical Research Institute']
# Number of Keywords: 6
# article # 3
# ['Unemployment', 'Medicine and Health', 'Polls and Public Opinion', 'Recession and Depression', 'Pain-Relieving Drugs', 'Weight', 'Exercise']
# Number of Keywords: 7
# article # 4
# ['Pain-Relieving Drugs', 'Drug Abuse and Traffic', 'Li, Stan Xuhui', 'New York City', 'Sentences (Criminal)', 'Flushing (Queens, NY)', 'Sonberg, Michael R', 'Drugs (Pharmaceuticals)']
# Number of Keywords: 8
# article # 5
# ['Thomas, Katie', 'Pain-Relieving Drugs', 'Drug Abuse and Traffic', 'Express Scripts Inc', 'Drugs (Pharmaceuticals)', 'Centers for Disease Control and Prevention']
# Number of Keywords: 6
# article # 6
# ['Goodman, J David', 'Heroin', 'Pain-Relieving Drugs', 'Drug Abuse and Traffic', 'Police', 'Drugs (Pharmaceuticals)', 'Naloxone (Drug)', 'Prices (Fares, Fees and Rates)']
# Number of Keywords: 8
# article # 7
# ['Thomas, Katie', 'Insys Therapeutics Inc.', 'Pain-Relieving Drugs', 'Doctors', 'ADVERTISING AND MARKETING', 'Malpractice', 'Texas', 'Drugs (Pharmaceuticals)', 'United States']
# Number of Keywords: 9
# article # 8
# ['Tavernise, Sabrina', 'Food and Drug Administration', 'Steroids', 'Neck', 'Back (Human Body Part)', 'Pain-Relieving Drugs', 'Labeling and Labels', 'Pain']
# Number of Keywords: 8
# article # 9
# ['Rabin, Roni Caryn', 'Pain-Relieving Drugs', 'Food and Drug Administration', 'Drug Abuse and Traffic', 'Drugs (Pharmaceuticals)', 'Pain', 'Zohydro (Drug)']
# Number of Keywords: 7
# article # 0
# ['Schwarz, Alan', 'Drug Abuse and Traffic', 'Pain-Relieving Drugs', 'Teenagers and Adolescence', 'National Institute on Drug Abuse', 'Smoking and Tobacco', 'Marijuana', 'E-Cigarettes', 'Drugs (Pharmaceuticals)']
# Number of Keywords: 9
# article # 1
# ['Children and Childhood', 'Death and Dying', 'Families and Family Life', 'Hospice Care', 'Pain-Relieving Drugs']
# Number of Keywords: 5
# article # 2
# ['Emergency Medical Treatment', 'Health Insurance and Managed Care', 'Hospitals', 'Minorities', 'Pain-Relieving Drugs']
# Number of Keywords: 5
# article # 3
# ['Drugs (Pharmaceuticals)', 'Elderly', 'Labeling and Labels (Product)', 'Pain-Relieving Drugs']
# Number of Keywords: 4
# article # 4
# ['Pain-Relieving Drugs', 'Friedman, Richard A', 'Deaths (Fatalities)', 'Doctors', 'United States', 'Drugs (Pharmaceuticals)', 'Addiction (Psychology)', 'OxyContin (Drug)', 'Social Conditions and Trends']
# Number of Keywords: 9
# article # 5
# ['Drug Abuse and Traffic', 'Presidential Election of 2016', 'Obama, Barack', 'Sanders, Bernard', 'Clinton, Hillary Rodham', 'Fiorina, Carleton S', 'Christie, Christopher J', 'Bush, Jeb', 'Drugs (Pharmaceuticals)', 'Heroin', 'Pain-Relieving Drugs', 'ALCOHOL ABUSE']
# Number of Keywords: 12
# article # 6
# ['Harris, Gardiner', 'Pain-Relieving Drugs', 'Drug Abuse and Traffic', 'West Virginia', 'Purdue Pharma', 'Austin (Ind)', 'Centers for Disease Control and Prevention']
# Number of Keywords: 7
# article # 7
# ['Schwarz, Alan', 'Drug Enforcement Administration', 'Drugstores', 'Pain-Relieving Drugs', 'Drug Abuse and Traffic', 'Waste Materials and Disposal', 'Walgreen Co.', 'Environment', 'CVS Caremark Corporation', 'Drugs (Pharmaceuticals)', 'United States']
# Number of Keywords: 11
# article # 8
# ['Saint Louis, Catherine', 'Pain-Relieving Drugs', 'OxyContin (Drug)', 'Drug Abuse and Traffic', 'Food and Drug Administration', 'Children and Childhood', 'Clinton, Hillary Rodham', 'Cancer', 'AMERICAN ACADEMY OF PEDIATRICS', 'Purdue Pharma', 'Physicians for Responsible Opioid Prescribing', 'Ostroff, Stephen']
# Number of Keywords: 12
# article # 9
# ['Biotechnology and Bioengineering', 'Pain-Relieving Drugs', 'Science (Journal)', 'Drug Abuse and Traffic', 'Yeast', 'Poppies', 'Opium', 'Drugs (Pharmaceuticals)', 'Smolke, Christina D (1975- )', 'Oye, Kenneth A (1949- )']
# Number of Keywords: 10
# article # 0
# ['Pain-Relieving Drugs', 'Bakalar, Nicholas', 'Drug Abuse and Traffic', 'Deaths (Fatalities)', 'Centers for Disease Control and Prevention', 'Opium', 'Heroin']
# Number of Keywords: 7
# article # 1
# ['Babies and Infants', 'Saint Louis, Catherine', 'Rural Areas', 'Pain-Relieving Drugs', 'Drug Abuse and Traffic', 'Pregnancy and Childbirth', 'JAMA Pediatrics (Journal)', 'Research']
# Number of Keywords: 8
# article # 2
# ['Pain-Relieving Drugs', 'Drug Abuse and Traffic', 'Heroin', 'Long Island (NY)', 'Deaths (Fatalities)', 'Drugs (Pharmaceuticals)']
# Number of Keywords: 6
# article # 3
# ['Dr. Feelgood: Dealer or Healer? (Movie)', 'Hurwitz, William Eliot', 'Marson, Eve', 'Pain-Relieving Drugs', 'Drug Abuse and Traffic', 'Documentary Films and Programs', 'Movies']
# Number of Keywords: 7
# article # 4
# ['Medicine and Health', 'Drugs (Pharmaceuticals)', 'Viruses', 'Health Insurance and Managed Care', 'Zika Virus', 'Schizophrenia', 'Mental Health and Disorders', 'Pain', 'Pain-Relieving Drugs', 'Teeth and Dentistry', 'Weight', 'Obesity', 'Diet and Nutrition', 'Birth Control and Family Planning', 'Cancer', 'Immune System', 'Plumbing', 'Transplants']
# Number of Keywords: 18
# article # 5
# ['Pain-Relieving Drugs', 'Bakalar, Nicholas', 'Pain', 'Babies and Infants', 'Vaccination and Immunization']
# Number of Keywords: 5
# article # 6
# ['Ears and Hearing', 'Bakalar, Nicholas', 'Drugs (Pharmaceuticals)', 'American Journal of Epidemiology', 'Tylenol (Drug)', 'Ibuprofen (Drug)', 'Aspirin', 'Pain-Relieving Drugs']
# Number of Keywords: 8
# article # 7
# ['Seelye, Katharine Q', 'Group Homes and Supportive Housing', 'Drug Abuse and Traffic', 'Pregnancy and Childbirth', 'Hope on Haven Hill', 'Rochester (NH)', 'New Hampshire', 'Pain-Relieving Drugs', 'Therapy and Rehabilitation']
# Number of Keywords: 9
# article # 8
# ['Murders, Attempted Murders and Homicides', 'Duterte, Rodrigo', 'Philippines', 'Drug Abuse and Traffic', 'Pain-Relieving Drugs']
# Number of Keywords: 5
# article # 9
# ['Thomas, Katie', 'Insys Therapeutics Inc', 'Pain-Relieving Drugs', 'Drugs (Pharmaceuticals)', 'Bribery and Kickbacks', 'Racketeering and Racketeers', 'Babich, Michael L']
# Number of Keywords: 7
# article # 0
# ['Foster Care', 'Children and Childhood', 'Drug Abuse and Traffic', 'Pain-Relieving Drugs', 'Addiction (Psychology)']
# Number of Keywords: 5
# article # 1
# ['Cherokee Indians', 'Pain-Relieving Drugs', 'Addiction (Psychology)', 'Suits and Litigation (Civil)', 'AMERISOURCEBERGEN CORP', 'CVS Caremark Corporation', 'Cardinal Health Inc', 'Walgreen Co.']
# Number of Keywords: 8
# article # 2
# ['Drug Abuse and Traffic', 'Blacks', 'Deaths (Fatalities)', 'National Center for Health Statistics', 'Heroin', 'States (US)', 'Centers for Disease Control and Prevention', 'Pain-Relieving Drugs']
# Number of Keywords: 8
# article # 3
# ['Pain-Relieving Drugs', 'Addiction (Psychology)', 'Dietary Supplements and Herbal Remedies', 'ADVERTISING AND MARKETING', 'Center for Science in the Public Interest', 'Food and Drug Administration']
# Number of Keywords: 6
# article # 4
# ['Conway, Kellyanne', 'Pain-Relieving Drugs', 'United States Politics and Government', 'Addiction (Psychology)', 'Drug Abuse and Traffic', 'APPOINTMENTS AND EXECUTIVE CHANGES', 'Drug Enforcement Administration', 'Trump, Donald J']
# Number of Keywords: 8
# article # 5
# ['Drug Abuse and Traffic', 'Pain-Relieving Drugs', 'Education (K-12)', 'Trump, Donald J', 'Parenting', 'United States Politics and Government']
# Number of Keywords: 6
# article # 6
# ['Pain-Relieving Drugs', 'Drug Abuse and Traffic', 'Drugs (Pharmaceuticals)', 'Suits and Litigation (Civil)', 'Local Government']
# Number of Keywords: 5
# article # 7
# ['Drug Abuse and Traffic', 'Addiction (Psychology)', 'American Addiction Centers', 'Cartwright, Michael', 'Benefield, Gary (d 2010)', 'Drose, Chris', 'Pain-Relieving Drugs', 'Health Insurance and Managed Care', 'Therapy and Rehabilitation', 'Hill, Charles']
# Number of Keywords: 10
# article # 8
# ['Pain-Relieving Drugs', 'Surgery and Surgeons', 'Ibuprofen (Drug)', 'Tylenol (Drug)']
# Number of Keywords: 4
# article # 9
# ['Uganda', 'Pain-Relieving Drugs', 'Morphine', 'Pain', 'Hospice Care', 'ACQUIRED IMMUNE DEFICIENCY SYNDROME', 'Cancer']
# Number of Keywords: 7
# article # 0
# ['Pain-Relieving Drugs', 'Suits and Litigation (Civil)', 'Addiction (Psychology)', 'Opioids and Opiates', 'Purdue Pharma', 'Sackler, Richard (1945- )']
# Number of Keywords: 6
# article # 1
# ['Heroin', 'Opioids and Opiates', 'Addiction (Psychology)', 'Drug Abuse and Traffic', 'Therapy and Rehabilitation', 'Buprenorphine (Drug)', 'Naloxone (Drug)', 'Methadone', 'Dopamine', 'your-feed-graphics']
# Number of Keywords: 10
# article # 2
# ['Heroin', 'Drug Abuse and Traffic', 'Addiction (Psychology)', 'Opioids and Opiates']
# Number of Keywords: 4
# article # 3
# ['Books and Literature', 'Opioids and Opiates', 'Addiction (Psychology)', 'OxyContin (Drug)']
# Number of Keywords: 4
# article # 4
# ['Drug Abuse and Traffic', 'Addiction (Psychology)', 'Opioids and Opiates', 'Heroin', 'West Virginia', 'Drugs (Pharmaceuticals)', 'your-feed-photojournalism']
# Number of Keywords: 7
# article # 5
# ['Drug Abuse and Traffic', 'Nine-One-One (911) (Emergency Phone Number)', 'Emergency Medical Treatment', 'Fentanyl', 'Opioids and Opiates', 'Hatton, Scotty', 'Weil, Eric (1968- )', 'Wightman, Scottie', 'ALTON (NH)']
# Number of Keywords: 9
# article # 6
# ['Purdue Pharma', 'OxyContin (Drug)', 'Addiction (Psychology)', 'Drug Abuse and Traffic', 'Opioids and Opiates', 'Pain', 'Drugs (Pharmaceuticals)', 'Mental Health and Disorders']
# Number of Keywords: 8
# article # 7
# ['Opioids and Opiates', 'Michigan', 'Frauds and Swindling', 'Doctors', 'Health Insurance and Managed Care', 'OxyContin (Drug)', 'Medicaid', 'Medicare', 'Bothra, Rajendra', 'Backos, Eric', 'Edu, Ganiu', 'Lewis, David L (1977- )', 'Russo, Christopher R (1968- )', 'Kufner, Ronald P (1950- )']
# Number of Keywords: 14
# article # 8
# ['Opioids and Opiates', 'Drug Abuse and Traffic', 'Addiction (Psychology)', 'JourneyPure at the River (Murfreesboro, Tenn)', 'Loyd, Stephen D (1967- )', 'Buprenorphine (Drug)', 'Therapy and Rehabilitation', 'Pain-Relieving Drugs', 'Methadone', 'Heroin', 'Tennessee']
# Number of Keywords: 11
# article # 9
# ['Opioids and Opiates', 'Heroin', 'Addiction (Psychology)', 'Health Insurance and Managed Care', 'Buprenorphine (Drug)', 'Methadone']
# Number of Keywords: 6
# article # 0
# ['Opioids and Opiates', 'OxyContin (Drug)', 'Drugs (Pharmaceuticals)', 'Pain-Relieving Drugs', 'Fentanyl', 'Regulation and Deregulation of Industry', 'Food and Drug Administration', 'your-feed-healthcare', 'Drug Abuse and Traffic']
# Number of Keywords: 9
# article # 1
# ['Drug Abuse and Traffic', 'Opioids and Opiates', 'Factories and Manufacturing', 'Automobiles', 'Deaths (Fatalities)', 'JAMA Internal Medicine (Journal)', 'Shutdowns (Institutional)', 'Venkataramani, Atheendar', 'University of Pennsylvania']
# Number of Keywords: 9
# article # 2
# ['Drug Abuse and Traffic', 'Marijuana', 'Baseball', 'Tests (Drug Use)', 'Opioids and Opiates', 'Major League Baseball', 'Major League Baseball Players Assn', 'Skaggs, Tyler (1991-2019)']
# Number of Keywords: 8
# article # 3
# ['Suits and Litigation (Civil)', 'Sackler Family', 'Bankruptcies', 'Pain-Relieving Drugs', 'Opioids and Opiates', 'Purdue Pharma', 'Corporate Taxes', 'your-feed-healthcare']
# Number of Keywords: 8
# article # 4
# ['Sackler Family', 'Tufts University', 'Names, Organizational', 'Opioids and Opiates', 'Colleges and Universities', 'Sackler, Arthur M (1913-1987)', 'Purdue Pharma']
# Number of Keywords: 7
# article # 5
# ['Drug Abuse and Traffic', 'Education (K-12)', 'Opioids and Opiates', 'OxyContin (Drug)', 'Heroin', 'Minford (Ohio)', 'Scioto County (Ohio)', 'Purdue Pharma', 'Ohio', 'Teenagers and Adolescence']
# Number of Keywords: 10
# article # 6
# ['Two Thousand Nineteen', 'Corporate Social Responsibility', 'Mobile Applications', 'Computers and the Internet', 'Social Media', 'Start-ups', 'Entrepreneurship', 'Greenhouse Gas Emissions', 'Nonprofit Organizations', 'Pinterest', 'OpenAQ', 'Opioids and Opiates', 'DynamiCare Health', 'Biobot Analytics Inc', 'Pear Therapeutics Inc', 'Lemontree Foods Inc', 'Delivery Services', 'Propel Inc', 'Food']
# Number of Keywords: 19
# article # 7
# ['Swimming', 'AMPUTATION', 'Paralympic Games', 'Stickney, Morgan', 'Pain-Relieving Drugs', 'Opioids and Opiates']
# Number of Keywords: 6
# article # 8
# ['Foster Care', 'Children and Childhood', 'Drug Abuse and Traffic', 'Addiction (Psychology)', 'Opioids and Opiates', 'PORTSMOUTH (OHIO)', 'Scioto County (Ohio)', 'Ohio', 'Families and Family Life']
# Number of Keywords: 9
# article # 9
# ['Methamphetamines', 'Drug Abuse and Traffic', 'Deaths (Fatalities)', 'Addiction (Psychology)', 'Opioids and Opiates', 'Oklahoma', 'States (US)', 'your-feed-healthcare']
# Number of Keywords: 8

# %%
kw_by_doc
# Out:
# [['ARTHRITIS AND RHEUMATISM',
#   'Elderly',
#   'Drugs (Pharmaceuticals)',
#   'Pain-Relieving Drugs'],
#  ['DURA AUTOMOTIVE SYSTEMS INCORPORATED',
#   'Tests and Testing',
#   'Pain-Relieving Drugs',
#   'ACCIDENTS AND SAFETY',
#   'Drugs (Pharmaceuticals)',
#   'Drug Abuse and Traffic',
#   'Labor and Jobs'],
#  ['Drug Abuse and Traffic',
#   'Drugs (Pharmaceuticals)',
#   'Drug Enforcement Administration',
#   'Pain-Relieving Drugs'],
#  ['OxyContin (Drug)',
#   'Pain-Relieving Drugs',
#   'Elderly',
#   'Cocaine and Crack Cocaine',
#   'San Francisco (Calif)',
#   'Drug Abuse and Traffic'],
#  ['Pain-Relieving Drugs',
#   'Pain',
#   'Books and Literature',
#   'Medicine and Health',
#   'ANESTHESIA AND ANESTHETICS',
#   'Thernstrom, Melanie'],
#  ['Doctors',
#   'Washington (State)',
#   'Drugs (Pharmaceuticals)',
#   'Regulation and Deregulation of Industry',
#   'Pain-Relieving Drugs'],
#  ['Medicine and Health', 'Drugs (Pharmaceuticals)', 'Deaths (Obituaries)'],
#  ['Pain',
#   'Drug Abuse and Traffic',
#   'Medicine and Health',
#   'Emergency Medical Treatment'],
#  ['Fibromyalgia', 'Medicine and Health', 'Pain', 'Pain-Relieving Drugs'],
#  [],
#  ['Automobiles',
#   'Poisoning and Poisons',
#   'Deaths (Fatalities)',
#   'Drugs (Pharmaceuticals)',
#   'Pain-Relieving Drugs',
#   'National Center for Health Statistics',
#   'Statistics',
#   'Traffic Accidents and Safety'],
#  ['Aspirin',
#   'Pain-Relieving Drugs',
#   'Asthma',
#   'Medicine and Health',
#   'Research',
#   'Children and Childhood'],
#  ['Pain-Relieving Drugs',
#   'Sports Injuries',
#   'Football',
#   'Medicine and Health',
#   'National Football League',
#   'Denver Broncos'],
#  ['Concussions',
#   'Pain-Relieving Drugs',
#   'Sports Injuries',
#   'Football',
#   'Pathon, Jerome',
#   'Horn, Joe',
#   'National Football League',
#   'Suits and Litigation',
#   'Joyce, Matt'],
#  ['Series',
#   'Fedoruk, Todd',
#   'Hockey, Ice',
#   'Boogaard, Derek',
#   'Concussions',
#   'Pain-Relieving Drugs',
#   'Sports Injuries',
#   'Canada',
#   'National Hockey League',
#   'Laraque, Georges',
#   'Minnesota Wild'],
#  ['Series',
#   'Hockey, Ice',
#   'Boogaard, Derek',
#   'National Hockey League',
#   'Pain-Relieving Drugs',
#   'ALCOHOL ABUSE',
#   'Sports Injuries',
#   'Drug Abuse and Traffic',
#   'Canada',
#   'New York Rangers',
#   'Concussions',
#   'Minnesota Wild'],
#  ['Hospitals',
#   'Elderly',
#   'Medicine and Health',
#   'Emergency Medical Treatment',
#   'Pain-Relieving Drugs'],
#  ['Pain-Relieving Drugs',
#   'Drugs (Pharmaceuticals)',
#   'New York City',
#   'New York City Health and Hospitals Corp',
#   'Robberies and Thefts',
#   'Hospitals',
#   'Organized Crime'],
#  ['Crime and Criminals',
#   'Pain-Relieving Drugs',
#   'Decisions and Verdicts',
#   'September 11 (2001)',
#   'Teeth and Dentistry',
#   'Attention Deficit Hyperactivity Disorder'],
#  ['Drug Abuse and Traffic',
#   'Drugs (Pharmaceuticals)',
#   'Naloxone (Drug)',
#   'Pain',
#   'Pain-Relieving Drugs',
#   'Food and Drug Administration',
#   'National Institute on Drug Abuse'],
#  ['Pain-Relieving Drugs',
#   'Drugs (Pharmaceuticals)',
#   'Flushing (NYC)',
#   'Laffer, David S',
#   'Doctors',
#   'Li, Stan Xuhui',
#   'Murders and Attempted Murders'],
#  ['Drugstores',
#   'Pain-Relieving Drugs',
#   'Drugs (Pharmaceuticals)',
#   'AMERISOURCEBERGEN CORP',
#   'Cardinal Health Inc',
#   'Drug Abuse and Traffic',
#   'Drug Enforcement Administration'],
#  ['Steroids', 'Drugs (Pharmaceuticals)', 'Meningitis', 'Pain-Relieving Drugs'],
#  ['New England Compounding Center',
#   'Factories and Manufacturing',
#   'Deaths (Fatalities)',
#   'Drugs (Pharmaceuticals)',
#   'Meningitis',
#   'Steroids',
#   'Pain-Relieving Drugs',
#   'Health Insurance and Managed Care',
#   'Food and Drug Administration'],
#  ['Addiction (Psychology)', 'Drug Abuse and Traffic', 'Pain-Relieving Drugs'],
#  ['Cancer', 'Doctors', 'Pain', 'Pain-Relieving Drugs'],
#  ['Regulation and Deregulation of Industry',
#   'Pain-Relieving Drugs',
#   'Drugs (Pharmaceuticals)',
#   'Drug Abuse and Traffic',
#   'Labeling and Labels',
#   'Food and Drug Administration'],
#  ['Drug Abuse and Traffic',
#   'Drugs (Pharmaceuticals)',
#   'OxyContin (Drug)',
#   'Pain-Relieving Drugs',
#   'FARLEY, THOMAS',
#   'Schneiderman, Eric T'],
#  ['Cocaine and Crack Cocaine',
#   'Heroin',
#   'Pain-Relieving Drugs',
#   'United States',
#   'Drugs (Pharmaceuticals)',
#   'Mexico',
#   'Drug Abuse and Traffic',
#   'Drug Enforcement Administration'],
#  ['Drugs (Pharmaceuticals)', 'Pain-Relieving Drugs'],
#  ['Sontag, Deborah',
#   'Buprenorphine (Drug)',
#   'Addiction (Psychology)',
#   'Drug Abuse and Traffic',
#   'Therapy and Rehabilitation',
#   'Pain-Relieving Drugs',
#   'Clark, Allan W',
#   'Smith, Todd',
#   'Sullivan, Carl R III',
#   'Series'],
#  ['Pain-Relieving Drugs',
#   'Meier, Barry',
#   'Drug Abuse and Traffic',
#   'Addiction (Psychology)',
#   'ALKERMES INC',
#   'Elan Corporation PLC',
#   'Food and Drug Administration',
#   'Conflicts of Interest'],
#  ['Meier, Barry',
#   'Pain-Relieving Drugs',
#   'Suits and Litigation (Civil)',
#   'ADVERTISING AND MARKETING',
#   'Drug Abuse and Traffic',
#   'Subpoenas',
#   'Chicago (Ill)',
#   'Cook County (Ill)',
#   'Janssen Pharmaceutica',
#   'Purdue Pharma',
#   'Endo Pharmaceuticals Inc'],
#  ['Food and Drug Administration',
#   'Pain-Relieving Drugs',
#   'Drug Abuse and Traffic',
#   'Regulation and Deregulation of Industry',
#   'Editorials'],
#  ['Meier, Barry',
#   'Drug Abuse and Traffic',
#   'Lipton, Eric',
#   'Pain-Relieving Drugs',
#   'Food and Drug Administration',
#   'Manchin, Joe III',
#   'Upton, Fred',
#   'United States Politics and Government',
#   'Senate',
#   'House of Representatives'],
#  ['Meier, Barry',
#   'Drugs (Pharmaceuticals)',
#   'Pain-Relieving Drugs',
#   'Food and Drug Administration',
#   'Drug Abuse and Traffic',
#   'Regulation and Deregulation of Industry',
#   'Woodcock, Janet'],
#  ['Blacks',
#   'Children and Childhood',
#   'Emergency Medical Treatment',
#   'Hispanic-Americans',
#   'Hospitals',
#   'Minorities',
#   'Pain-Relieving Drugs',
#   'Race and Ethnicity'],
#  ['ANESTHESIA AND ANESTHETICS',
#   'Back (Human Body Part)',
#   'Pain',
#   'Pain-Relieving Drugs',
#   'Steroids'],
#  ['Pain-Relieving Drugs',
#   'Labeling and Labels',
#   'Drug Abuse and Traffic',
#   'Physicians for Responsible Opioid Prescribing',
#   'Food and Drug Administration',
#   'Editorials'],
#  ['Tavernise, Sabrina',
#   'Food and Drug Administration',
#   'Drug Abuse and Traffic',
#   'Drugs (Pharmaceuticals)',
#   'Pain-Relieving Drugs',
#   'Labeling and Labels',
#   'Physicians for Responsible Opioid Prescribing',
#   'OxyContin (Drug)'],
#  ['Drug Abuse and Traffic',
#   'Pain-Relieving Drugs',
#   'Drugs (Pharmaceuticals)',
#   'Buprenorphine (Drug)',
#   'Pain',
#   'Food and Drug Administration',
#   'Regulation and Deregulation of Industry'],
#  ['United States', 'Drug Abuse and Traffic', 'Pain-Relieving Drugs', 'Pain'],
#  ['Aspirin',
#   'Pain-Relieving Drugs',
#   'Skin Cancer',
#   'Olsen, Catherine M',
#   'Journal of Investigative Dermatology',
#   'QIMR Berghofer Medical Research Institute'],
#  ['Unemployment',
#   'Medicine and Health',
#   'Polls and Public Opinion',
#   'Recession and Depression',
#   'Pain-Relieving Drugs',
#   'Weight',
#   'Exercise'],
#  ['Pain-Relieving Drugs',
#   'Drug Abuse and Traffic',
#   'Li, Stan Xuhui',
#   'New York City',
#   'Sentences (Criminal)',
#   'Flushing (Queens, NY)',
#   'Sonberg, Michael R',
#   'Drugs (Pharmaceuticals)'],
#  ['Thomas, Katie',
#   'Pain-Relieving Drugs',
#   'Drug Abuse and Traffic',
#   'Express Scripts Inc',
#   'Drugs (Pharmaceuticals)',
#   'Centers for Disease Control and Prevention'],
#  ['Goodman, J David',
#   'Heroin',
#   'Pain-Relieving Drugs',
#   'Drug Abuse and Traffic',
#   'Police',
#   'Drugs (Pharmaceuticals)',
#   'Naloxone (Drug)',
#   'Prices (Fares, Fees and Rates)'],
#  ['Thomas, Katie',
#   'Insys Therapeutics Inc.',
#   'Pain-Relieving Drugs',
#   'Doctors',
#   'ADVERTISING AND MARKETING',
#   'Malpractice',
#   'Texas',
#   'Drugs (Pharmaceuticals)',
#   'United States'],
#  ['Tavernise, Sabrina',
#   'Food and Drug Administration',
#   'Steroids',
#   'Neck',
#   'Back (Human Body Part)',
#   'Pain-Relieving Drugs',
#   'Labeling and Labels',
#   'Pain'],
#  ['Rabin, Roni Caryn',
#   'Pain-Relieving Drugs',
#   'Food and Drug Administration',
#   'Drug Abuse and Traffic',
#   'Drugs (Pharmaceuticals)',
#   'Pain',
#   'Zohydro (Drug)'],
#  ['Schwarz, Alan',
#   'Drug Abuse and Traffic',
#   'Pain-Relieving Drugs',
#   'Teenagers and Adolescence',
#   'National Institute on Drug Abuse',
#   'Smoking and Tobacco',
#   'Marijuana',
#   'E-Cigarettes',
#   'Drugs (Pharmaceuticals)'],
#  ['Children and Childhood',
#   'Death and Dying',
#   'Families and Family Life',
#   'Hospice Care',
#   'Pain-Relieving Drugs'],
#  ['Emergency Medical Treatment',
#   'Health Insurance and Managed Care',
#   'Hospitals',
#   'Minorities',
#   'Pain-Relieving Drugs'],
#  ['Drugs (Pharmaceuticals)',
#   'Elderly',
#   'Labeling and Labels (Product)',
#   'Pain-Relieving Drugs'],
#  ['Pain-Relieving Drugs',
#   'Friedman, Richard A',
#   'Deaths (Fatalities)',
#   'Doctors',
#   'United States',
#   'Drugs (Pharmaceuticals)',
#   'Addiction (Psychology)',
#   'OxyContin (Drug)',
#   'Social Conditions and Trends'],
#  ['Drug Abuse and Traffic',
#   'Presidential Election of 2016',
#   'Obama, Barack',
#   'Sanders, Bernard',
#   'Clinton, Hillary Rodham',
#   'Fiorina, Carleton S',
#   'Christie, Christopher J',
#   'Bush, Jeb',
#   'Drugs (Pharmaceuticals)',
#   'Heroin',
#   'Pain-Relieving Drugs',
#   'ALCOHOL ABUSE'],
#  ['Harris, Gardiner',
#   'Pain-Relieving Drugs',
#   'Drug Abuse and Traffic',
#   'West Virginia',
#   'Purdue Pharma',
#   'Austin (Ind)',
#   'Centers for Disease Control and Prevention'],
#  ['Schwarz, Alan',
#   'Drug Enforcement Administration',
#   'Drugstores',
#   'Pain-Relieving Drugs',
#   'Drug Abuse and Traffic',
#   'Waste Materials and Disposal',
#   'Walgreen Co.',
#   'Environment',
#   'CVS Caremark Corporation',
#   'Drugs (Pharmaceuticals)',
#   'United States'],
#  ['Saint Louis, Catherine',
#   'Pain-Relieving Drugs',
#   'OxyContin (Drug)',
#   'Drug Abuse and Traffic',
#   'Food and Drug Administration',
#   'Children and Childhood',
#   'Clinton, Hillary Rodham',
#   'Cancer',
#   'AMERICAN ACADEMY OF PEDIATRICS',
#   'Purdue Pharma',
#   'Physicians for Responsible Opioid Prescribing',
#   'Ostroff, Stephen'],
#  ['Biotechnology and Bioengineering',
#   'Pain-Relieving Drugs',
#   'Science (Journal)',
#   'Drug Abuse and Traffic',
#   'Yeast',
#   'Poppies',
#   'Opium',
#   'Drugs (Pharmaceuticals)',
#   'Smolke, Christina D (1975- )',
#   'Oye, Kenneth A (1949- )'],
#  ['Pain-Relieving Drugs',
#   'Bakalar, Nicholas',
#   'Drug Abuse and Traffic',
#   'Deaths (Fatalities)',
#   'Centers for Disease Control and Prevention',
#   'Opium',
#   'Heroin'],
#  ['Babies and Infants',
#   'Saint Louis, Catherine',
#   'Rural Areas',
#   'Pain-Relieving Drugs',
#   'Drug Abuse and Traffic',
#   'Pregnancy and Childbirth',
#   'JAMA Pediatrics (Journal)',
#   'Research'],
#  ['Pain-Relieving Drugs',
#   'Drug Abuse and Traffic',
#   'Heroin',
#   'Long Island (NY)',
#   'Deaths (Fatalities)',
#   'Drugs (Pharmaceuticals)'],
#  ['Dr. Feelgood: Dealer or Healer? (Movie)',
#   'Hurwitz, William Eliot',
#   'Marson, Eve',
#   'Pain-Relieving Drugs',
#   'Drug Abuse and Traffic',
#   'Documentary Films and Programs',
#   'Movies'],
#  ['Medicine and Health',
#   'Drugs (Pharmaceuticals)',
#   'Viruses',
#   'Health Insurance and Managed Care',
#   'Zika Virus',
#   'Schizophrenia',
#   'Mental Health and Disorders',
#   'Pain',
#   'Pain-Relieving Drugs',
#   'Teeth and Dentistry',
#   'Weight',
#   'Obesity',
#   'Diet and Nutrition',
#   'Birth Control and Family Planning',
#   'Cancer',
#   'Immune System',
#   'Plumbing',
#   'Transplants'],
#  ['Pain-Relieving Drugs',
#   'Bakalar, Nicholas',
#   'Pain',
#   'Babies and Infants',
#   'Vaccination and Immunization'],
#  ['Ears and Hearing',
#   'Bakalar, Nicholas',
#   'Drugs (Pharmaceuticals)',
#   'American Journal of Epidemiology',
#   'Tylenol (Drug)',
#   'Ibuprofen (Drug)',
#   'Aspirin',
#   'Pain-Relieving Drugs'],
#  ['Seelye, Katharine Q',
#   'Group Homes and Supportive Housing',
#   'Drug Abuse and Traffic',
#   'Pregnancy and Childbirth',
#   'Hope on Haven Hill',
#   'Rochester (NH)',
#   'New Hampshire',
#   'Pain-Relieving Drugs',
#   'Therapy and Rehabilitation'],
#  ['Murders, Attempted Murders and Homicides',
#   'Duterte, Rodrigo',
#   'Philippines',
#   'Drug Abuse and Traffic',
#   'Pain-Relieving Drugs'],
#  ['Thomas, Katie',
#   'Insys Therapeutics Inc',
#   'Pain-Relieving Drugs',
#   'Drugs (Pharmaceuticals)',
#   'Bribery and Kickbacks',
#   'Racketeering and Racketeers',
#   'Babich, Michael L'],
#  ['Foster Care',
#   'Children and Childhood',
#   'Drug Abuse and Traffic',
#   'Pain-Relieving Drugs',
#   'Addiction (Psychology)'],
#  ['Cherokee Indians',
#   'Pain-Relieving Drugs',
#   'Addiction (Psychology)',
#   'Suits and Litigation (Civil)',
#   'AMERISOURCEBERGEN CORP',
#   'CVS Caremark Corporation',
#   'Cardinal Health Inc',
#   'Walgreen Co.'],
#  ['Drug Abuse and Traffic',
#   'Blacks',
#   'Deaths (Fatalities)',
#   'National Center for Health Statistics',
#   'Heroin',
#   'States (US)',
#   'Centers for Disease Control and Prevention',
#   'Pain-Relieving Drugs'],
#  ['Pain-Relieving Drugs',
#   'Addiction (Psychology)',
#   'Dietary Supplements and Herbal Remedies',
#   'ADVERTISING AND MARKETING',
#   'Center for Science in the Public Interest',
#   'Food and Drug Administration'],
#  ['Conway, Kellyanne',
#   'Pain-Relieving Drugs',
#   'United States Politics and Government',
#   'Addiction (Psychology)',
#   'Drug Abuse and Traffic',
#   'APPOINTMENTS AND EXECUTIVE CHANGES',
#   'Drug Enforcement Administration',
#   'Trump, Donald J'],
#  ['Drug Abuse and Traffic',
#   'Pain-Relieving Drugs',
#   'Education (K-12)',
#   'Trump, Donald J',
#   'Parenting',
#   'United States Politics and Government'],
#  ['Pain-Relieving Drugs',
#   'Drug Abuse and Traffic',
#   'Drugs (Pharmaceuticals)',
#   'Suits and Litigation (Civil)',
#   'Local Government'],
#  ['Drug Abuse and Traffic',
#   'Addiction (Psychology)',
#   'American Addiction Centers',
#   'Cartwright, Michael',
#   'Benefield, Gary (d 2010)',
#   'Drose, Chris',
#   'Pain-Relieving Drugs',
#   'Health Insurance and Managed Care',
#   'Therapy and Rehabilitation',
#   'Hill, Charles'],
#  ['Pain-Relieving Drugs',
#   'Surgery and Surgeons',
#   'Ibuprofen (Drug)',
#   'Tylenol (Drug)'],
#  ['Uganda',
#   'Pain-Relieving Drugs',
#   'Morphine',
#   'Pain',
#   'Hospice Care',
#   'ACQUIRED IMMUNE DEFICIENCY SYNDROME',
#   'Cancer'],
#  ['Pain-Relieving Drugs',
#   'Suits and Litigation (Civil)',
#   'Addiction (Psychology)',
#   'Opioids and Opiates',
#   'Purdue Pharma',
#   'Sackler, Richard (1945- )'],
#  ['Heroin',
#   'Opioids and Opiates',
#   'Addiction (Psychology)',
#   'Drug Abuse and Traffic',
#   'Therapy and Rehabilitation',
#   'Buprenorphine (Drug)',
#   'Naloxone (Drug)',
#   'Methadone',
#   'Dopamine',
#   'your-feed-graphics'],
#  ['Heroin',
#   'Drug Abuse and Traffic',
#   'Addiction (Psychology)',
#   'Opioids and Opiates'],
#  ['Books and Literature',
#   'Opioids and Opiates',
#   'Addiction (Psychology)',
#   'OxyContin (Drug)'],
#  ['Drug Abuse and Traffic',
#   'Addiction (Psychology)',
#   'Opioids and Opiates',
#   'Heroin',
#   'West Virginia',
#   'Drugs (Pharmaceuticals)',
#   'your-feed-photojournalism'],
#  ['Drug Abuse and Traffic',
#   'Nine-One-One (911) (Emergency Phone Number)',
#   'Emergency Medical Treatment',
#   'Fentanyl',
#   'Opioids and Opiates',
#   'Hatton, Scotty',
#   'Weil, Eric (1968- )',
#   'Wightman, Scottie',
#   'ALTON (NH)'],
#  ['Purdue Pharma',
#   'OxyContin (Drug)',
#   'Addiction (Psychology)',
#   'Drug Abuse and Traffic',
#   'Opioids and Opiates',
#   'Pain',
#   'Drugs (Pharmaceuticals)',
#   'Mental Health and Disorders'],
#  ['Opioids and Opiates',
#   'Michigan',
#   'Frauds and Swindling',
#   'Doctors',
#   'Health Insurance and Managed Care',
#   'OxyContin (Drug)',
#   'Medicaid',
#   'Medicare',
#   'Bothra, Rajendra',
#   'Backos, Eric',
#   'Edu, Ganiu',
#   'Lewis, David L (1977- )',
#   'Russo, Christopher R (1968- )',
#   'Kufner, Ronald P (1950- )'],
#  ['Opioids and Opiates',
#   'Drug Abuse and Traffic',
#   'Addiction (Psychology)',
#   'JourneyPure at the River (Murfreesboro, Tenn)',
#   'Loyd, Stephen D (1967- )',
#   'Buprenorphine (Drug)',
#   'Therapy and Rehabilitation',
#   'Pain-Relieving Drugs',
#   'Methadone',
#   'Heroin',
#   'Tennessee'],
#  ['Opioids and Opiates',
#   'Heroin',
#   'Addiction (Psychology)',
#   'Health Insurance and Managed Care',
#   'Buprenorphine (Drug)',
#   'Methadone'],
#  ['Opioids and Opiates',
#   'OxyContin (Drug)',
#   'Drugs (Pharmaceuticals)',
#   'Pain-Relieving Drugs',
#   'Fentanyl',
#   'Regulation and Deregulation of Industry',
#   'Food and Drug Administration',
#   'your-feed-healthcare',
#   'Drug Abuse and Traffic'],
#  ['Drug Abuse and Traffic',
#   'Opioids and Opiates',
#   'Factories and Manufacturing',
#   'Automobiles',
#   'Deaths (Fatalities)',
#   'JAMA Internal Medicine (Journal)',
#   'Shutdowns (Institutional)',
#   'Venkataramani, Atheendar',
#   'University of Pennsylvania'],
#  ['Drug Abuse and Traffic',
#   'Marijuana',
#   'Baseball',
#   'Tests (Drug Use)',
#   'Opioids and Opiates',
#   'Major League Baseball',
#   'Major League Baseball Players Assn',
#   'Skaggs, Tyler (1991-2019)'],
#  ['Suits and Litigation (Civil)',
#   'Sackler Family',
#   'Bankruptcies',
#   'Pain-Relieving Drugs',
#   'Opioids and Opiates',
#   'Purdue Pharma',
#   'Corporate Taxes',
#   'your-feed-healthcare'],
#  ['Sackler Family',
#   'Tufts University',
#   'Names, Organizational',
#   'Opioids and Opiates',
#   'Colleges and Universities',
#   'Sackler, Arthur M (1913-1987)',
#   'Purdue Pharma'],
#  ['Drug Abuse and Traffic',
#   'Education (K-12)',
#   'Opioids and Opiates',
#   'OxyContin (Drug)',
#   'Heroin',
#   'Minford (Ohio)',
#   'Scioto County (Ohio)',
#   'Purdue Pharma',
#   'Ohio',
#   'Teenagers and Adolescence'],
#  ['Two Thousand Nineteen',
#   'Corporate Social Responsibility',
#   'Mobile Applications',
#   'Computers and the Internet',
#   'Social Media',
#   'Start-ups',
#   'Entrepreneurship',
#   'Greenhouse Gas Emissions',
#   'Nonprofit Organizations',
#   'Pinterest',
#   'OpenAQ',
#   'Opioids and Opiates',
#   'DynamiCare Health',
#   'Biobot Analytics Inc',
#   'Pear Therapeutics Inc',
#   'Lemontree Foods Inc',
#   'Delivery Services',
#   'Propel Inc',
#   'Food'],
#  ['Swimming',
#   'AMPUTATION',
#   'Paralympic Games',
#   'Stickney, Morgan',
#   'Pain-Relieving Drugs',
#   'Opioids and Opiates'],
#  ['Foster Care',
#   'Children and Childhood',
#   'Drug Abuse and Traffic',
#   'Addiction (Psychology)',
#   'Opioids and Opiates',
#   'PORTSMOUTH (OHIO)',
#   'Scioto County (Ohio)',
#   'Ohio',
#   'Families and Family Life'],
#  ['Methamphetamines',
#   'Drug Abuse and Traffic',
#   'Deaths (Fatalities)',
#   'Addiction (Psychology)',
#   'Opioids and Opiates',
#   'Oklahoma',
#   'States (US)',
#   'your-feed-healthcare']]

# %%
#Let's add the lists of keywords used in each article, as well as the number of keywords used in each article to our
#article table

text_df['key_words']=kw_by_doc
text_df['number_of_key_words']=number_of_kw

#
# One quesiton we can ask is: How Many Times was Each Keyword used in Our Sample?

# %%
#Here, we write a command that counts the usage of each keyword across all our articles

df = pandas.Series(sum([item for item in text_df.key_words], [])).value_counts()

# %%
#Let's turn it into a table of keywords by their frequency of use

df_1 = df.to_frame()
df_1
# Out:
#                                              0
# Pain-Relieving Drugs                        82
# Drug Abuse and Traffic                      55
# Drugs (Pharmaceuticals)                     38
# Opioids and Opiates                         20
# Addiction (Psychology)                      19
# Food and Drug Administration                15
# Pain                                        14
# Heroin                                      12
# OxyContin (Drug)                            10
# Medicine and Health                          9
# Purdue Pharma                                8
# Deaths (Fatalities)                          8
# Children and Childhood                       6
# Regulation and Deregulation of Industry      6
# Health Insurance and Managed Care            6
# Doctors                                      6
# Therapy and Rehabilitation                   5
# Drug Enforcement Administration              5
# Suits and Litigation (Civil)                 5
# United States                                5
# Buprenorphine (Drug)                         5
# Emergency Medical Treatment                  5
# Elderly                                      4
# Centers for Disease Control and Prevention   4
# Hospitals                                    4
# Steroids                                     4
# Meier, Barry                                 4
# Sports Injuries                              4
# Cancer                                       4
# Labeling and Labels                          4
# ...                                         ..
# Traffic Accidents and Safety                 1
# Horn, Joe                                    1
# New Hampshire                                1
# Washington (State)                           1
# Austin (Ind)                                 1
# Joyce, Matt                                  1
# American Journal of Epidemiology             1
# Frauds and Swindling                         1
# Duterte, Rodrigo                             1
# your-feed-photojournalism                    1
# Zohydro (Drug)                               1
# Morphine                                     1
# Tennessee                                    1
# Social Conditions and Trends                 1
# Loyd, Stephen D (1967- )                     1
# Cartwright, Michael                          1
# Deaths (Obituaries)                          1
# Backos, Eric                                 1
# Denver Broncos                               1
# AMERICAN ACADEMY OF PEDIATRICS               1
# QIMR Berghofer Medical Research Institute    1
# APPOINTMENTS AND EXECUTIVE CHANGES           1
# Decisions and Verdicts                       1
# Michigan                                     1
# Greenhouse Gas Emissions                     1
# Laraque, Georges                             1
# Major League Baseball                        1
# San Francisco (Calif)                        1
# ACCIDENTS AND SAFETY                         1
# Tests (Drug Use)                             1
#
# [306 rows x 1 columns]

# %%
#What does our distribution look like for keyword counts? It looks like there are 306 total uses of keywords in our 
#100 articles, that the maximum amont a keyword was used was 82 times, that our mean number of times a keyword ws used was 
#2.38 times, and that 75% of our frequency usage happens with keywords used more than 2 times.


df_1.describe()
# Out:
#                 0
# count  306.000000
# mean     2.375817
# std      6.284454
# min      1.000000
# 25%      1.000000
# 50%      1.000000
# 75%      2.000000
# max     82.000000

# %%
#The frequency data as it stands is messy and skewed right, let's only look at keywords with high frequencies of use
#for comparisons, so only those keywords with over 2 uses, representing 75% of our data

df_for_plot = df_1[df_1[0]>2]

# %%
#Let's plot the frequencies of keyword use on a bar-graph. From this we can begin to think of how stories relating 
#to opioids are categorized, tagged, and pitched by the NYTimes.

df_for_plot.plot(kind='bar', figsize=(20,10))

# %% [markdown]
# ## Gathering Text to Make a Corpus for Text Analysis
#
# We've shown a little bit of what you can do with the meta-data included in the data we scraped from the NYTImes API for each article. You could parse around this output datat for a bot and find other bits of data that would be interesting, however, when we are looking at News Paper articles, we are often most interested in the content of those articles, what are they saying?
#
# Being that we want to conduct a text analysis of the content of these articles, we must first gather this written content and collect it in a structured form for analysis, which means finding the relevant text data and getting it ready to save as its own text file.

# %%
#We start to do this by looking again at the response and document fields in our data. Where is the text of 
#interest? It looks like it might be contained in the abstract, lead paragraph, and snippet. 

data_list[0]['response']['docs'][0]
# Out:
# {'_id': 'nyt://article/d163a755-71d8-5fdb-a9e5-55b6560bf2f3',
#  'abstract': 'A review cited a higher risk of bone fracture, heart attack and death with use of narcotic-based drugs.',
#  'byline': {'organization': None,
#   'original': 'By Barry Meier',
#   'person': [{'firstname': 'Barry',
#     'lastname': 'Meier',
#     'middlename': None,
#     'organization': '',
#     'qualifier': None,
#     'rank': 1,
#     'role': 'reported',
#     'title': None}]},
#  'document_type': 'article',
#  'headline': {'content_kicker': None,
#   'kicker': None,
#   'main': 'Narcotic Painkillers May Pose Danger to Elderly Patients, Study Says',
#   'name': None,
#   'print_headline': 'Narcotic Painkillers, Thought Safer for Elderly Patients, May Pose More Risk, Study Says',
#   'seo': None,
#   'sub': None},
#  'keywords': [{'major': 'N',
#    'name': 'subject',
#    'rank': 1,
#    'value': 'ARTHRITIS AND RHEUMATISM'},
#   {'major': 'N', 'name': 'subject', 'rank': 2, 'value': 'Elderly'},
#   {'major': 'N',
#    'name': 'subject',
#    'rank': 3,
#    'value': 'Drugs (Pharmaceuticals)'},
#   {'major': 'N',
#    'name': 'subject',
#    'rank': 4,
#    'value': 'Pain-Relieving Drugs'}],
#  'lead_paragraph': ' Older patients with arthritis who take narcotic-based drugs to relieve pain face a higher risk of bone fracture, heart attack and death when compared to those taking non-narcotic drugs, according to a government-financed study published Monday.',
#  'multimedia': [],
#  'news_desk': 'Business',
#  'print_page': '3',
#  'print_section': 'B',
#  'pub_date': '2010-12-13T20:08:40+0000',
#  'section_name': 'Health',
#  'snippet': 'A review cited a higher risk of bone fracture, heart attack and death with use of narcotic-based drugs.',
#  'source': 'The New York Times',
#  'type_of_material': 'News',
#  'uri': 'nyt://article/d163a755-71d8-5fdb-a9e5-55b6560bf2f3',
#  'web_url': 'https://www.nytimes.com/2010/12/14/health/14drug.html',
#  'word_count': 635}

# %%
#What text is held in the abstract?

data_list[0]['response']['docs'][0]['abstract']
# Out:
# 'A review cited a higher risk of bone fracture, heart attack and death with use of narcotic-based drugs.'

# %%
#What text is held in the lead paragraph?

data_list[0]['response']['docs'][0]['lead_paragraph']
# Out:
# ' Older patients with arthritis who take narcotic-based drugs to relieve pain face a higher risk of bone fracture, heart attack and death when compared to those taking non-narcotic drugs, according to a government-financed study published Monday.'

# %%
#What text is held in the snippet? 

data_list[0]['response']['docs'][0]['snippet']
# Out:
# 'A review cited a higher risk of bone fracture, heart attack and death with use of narcotic-based drugs.'

# %% [markdown]
# A limitation of the article search API and the data we collected is that the full text of the article is not available, only a few text fields such as the abstract and snippet summarizing the article, and the lead paragraph of article itself.
#
# In our above example, the abstract and snippet are the same, but this is not the case with every article. For our purposes, let's just collect these three fields, and put them together into one text document for each article.

# %%
#Let's automate the collection of these three text fields, and merge them into one text, make a list of these texts,
#and add them to our article table.

text_by_article = list()

data_list_iter = range(len(data_list))

for d in data_list_iter:
    article_iter = range((len(data_list[d]['response']['docs'])))

    for a in article_iter:
        abstract = data_list[d]['response']['docs'][a]['abstract']
        lead_paragraph = data_list[d]['response']['docs'][a]['lead_paragraph']
        snippet = data_list[d]['response']['docs'][a]['snippet']
        text = abstract+lead_paragraph+snippet
        text_by_article.append(text)

# %%
#Here we look at the text collected for each article

text_by_article
# Out:
# ['A review cited a higher risk of bone fracture, heart attack and death with use of narcotic-based drugs. Older patients with arthritis who take narcotic-based drugs to relieve pain face a higher risk of bone fracture, heart attack and death when compared to those taking non-narcotic drugs, according to a government-financed study published Monday.A review cited a higher risk of bone fracture, heart attack and death with use of narcotic-based drugs.',
#  'Workplace testing is drawing complaints from employees who say they should not be fired for taking legal drugs.LAWRENCEBURG, Tenn. \x97 The news, delivered in a phone call, left Sue Bates aghast: she was losing her job of 22 years after testing positive for a legally prescribed drug. Workplace testing is drawing complaints from employees who say they should not be fired for taking legal drugs.',
#  'Drug users are breaking into people’s homes in search of prescription painkillers and other medications.BOSTON \x97 Police departments have collected thousands of handguns through buy-back programs in communities throughout the country. Now they want the contents of your medicine cabinet.Drug users are breaking into people’s homes in search of prescription painkillers and other medications.',
#  'San Francisco police officers say they are seeing more elderly, sick or disabled people selling their medications on the street.In Gregory Watts’s 13 years as a San Francisco police officer, he has arrested countless drug dealers. But only recently did he begin to notice that many of them resembled his grandparents.San Francisco police officers say they are seeing more elderly, sick or disabled people selling their medications on the street.',
#  'An expansive mix of medical reportage, history and memoir explores our relationship to pain.A simple understanding of pain would be this: It’s a biological response to injury or disease. Treat the cause and the pain abates. The body, after all, is a relatively efficient machine. But what happens when the wound won’t heal? And what if pain doesn’t stem from injury or disease, but is itself the problem?An expansive mix of medical reportage, history and memoir explores our relationship to pain.',
#  'Regulators in Washington State are attempting to stem what some see as the excessive use of prescribed narcotics.In an unusual move, a state government is developing regulations meant to stop doctors from prescribing higher doses of powerful \x97 and often dangerous \x97 pain killers for patients who are not benefiting from them.Regulators in Washington State are attempting to stem what some see as the excessive use of prescribed narcotics.',
#  'Mr. Lotsof’s belief that ibogaine could cure addiction to heroin persuaded the F.D.A. to approve a clinical trial, but the substance remains banned in the United States.Howard Lotsof was 19, addicted to heroin and searching for a new high in 1962 when he swallowed a bitter-tasting white powder taken from an exotic West African shrub. Mr. Lotsof’s belief that ibogaine could cure addiction to heroin persuaded the F.D.A. to approve a clinical trial, but the substance remains banned in the United States.',
#  'Emergency room visits for nonmedical use of prescription and over-the-counter drugs doubled during a recent five-year period.Emergency room visits for nonmedical use of prescription and over-the-counter drugs doubled during a recent five-year-period, the Centers for Disease Control and Prevention are reporting. Emergency room visits for nonmedical use of prescription and over-the-counter drugs doubled during a recent five-year period.',
# %%
#We take the text collected for each article and add it to our article table

text_df['text']=text_by_article

# %%
text_df
# Out:
#                      name  year  \
# 0              Meier_2010  2010
# 1             Zezima_2010  2010
# 2          Goodnough_2010  2010
# 3             Walter_2010  2010
# 4               Romm_2010  2010
# 5              Meier_2010  2010
# 6             Hevesi_2010  2010
# 7              Rabin_2010  2010
# 8   no_last_name_0_8_2010  2010
# 9             Wilson_2010  2010
# 10           Bakalar_2011  2011
# 11        Aschwanden_2011  2011
# 12           Jackson_2011  2011
# 13            Belson_2011  2011
# 14            Branch_2011  2011
# 15            Branch_2011  2011
# 16           Bakalar_2011  2011
# 17            Kaplan_2011  2011
# 18            Wilson_2011  2011
# 19         Szalavitz_2011  2011
# 20          Buettner_2012  2012
# 21             Meier_2012  2012
# 22           Pollack_2012  2012
# 23             Grady_2012  2012
# 24       Christopher_2012  2012
# 25              Chen_2012  2012
# 26             Meier_2012  2012
# 27       Hartocollis_2012  2012
# 28              Cave_2012  2012
# 29           Bakalar_2012  2012
# ..                    ...   ...
# 70           Lachman_2017  2017
# 71           Hoffman_2017  2017
# 72              Katz_2017  2017
# 73            Kaplan_2017  2017
# 74  no_last_name_7_4_2017  2017
# 75             Frakt_2017  2017
# 76             Smith_2017  2017
# 77           Corkery_2017  2017
# 78           Bakalar_2017  2017
# 79            McNeil_2017  2017
# 80             Meier_2018  2018
# 81             Sinha_2018  2018
# 82            Harlan_2018  2018
# 83             Zuger_2018  2018
# 84  no_last_name_8_4_2018  2018
# 85             Smith_2018  2018
# 86  no_last_name_8_6_2018  2018
# 87              None_2018  2018
# 88         Goodnough_2018  2018
# 89           Symonds_2018  2018
# 90         Goodnough_2019  2019
# 91           Chokshi_2019  2019
# 92            Wagner_2019  2019
# 93           Hoffman_2019  2019
# 94             Barry_2019  2019
# 95             Levin_2019  2019
# 96             Roose_2019  2019
# 97         Waldstein_2019  2019
# 98             Levin_2019  2019
# 99         Goodnough_2019  2019
#
#                                             key_words  number_of_key_words  \
# 0   [ARTHRITIS AND RHEUMATISM, Elderly, Drugs (Pha...                    4
# 1   [DURA AUTOMOTIVE SYSTEMS INCORPORATED, Tests a...                    7
# 2   [Drug Abuse and Traffic, Drugs (Pharmaceutical...                    4
# 3   [OxyContin (Drug), Pain-Relieving Drugs, Elder...                    6
# 4   [Pain-Relieving Drugs, Pain, Books and Literat...                    6
# 5   [Doctors, Washington (State), Drugs (Pharmaceu...                    5
# 6   [Medicine and Health, Drugs (Pharmaceuticals),...                    3
# 7   [Pain, Drug Abuse and Traffic, Medicine and He...                    4
# 8   [Fibromyalgia, Medicine and Health, Pain, Pain...                    4
# 9                                                  []                    0
# 10  [Automobiles, Poisoning and Poisons, Deaths (F...                    8
# 11  [Aspirin, Pain-Relieving Drugs, Asthma, Medici...                    6
# 12  [Pain-Relieving Drugs, Sports Injuries, Footba...                    6
# 98  [Foster Care, Children and Childhood, Drug Abu...                    9
# 99  [Methamphetamines, Drug Abuse and Traffic, Dea...                    8
#
#                                                  text
# 0   A review cited a higher risk of bone fracture,...
# 1   Workplace testing is drawing complaints from e...
# 2   Drug users are breaking into people’s homes in...
# 3   San Francisco police officers say they are see...
# 4   An expansive mix of medical reportage, history...
# 5   Regulators in Washington State are attempting ...
# 6   Mr. Lotsof’s belief that ibogaine could cure a...
# 7   Emergency room visits for nonmedical use of pr...
# 8   Mysterious pain, doubting doctors, depression,...
# 9   The pain killer and related drugs can cause fa...
# 10  Poisoning is now the leading cause of injury d...
# 11  More than 20 studies, including a large analys...
# 12  The N.F.L. should appoint a league-wide medica...
# 13  A dozen retired players contend that teams rep...
# 14  Over six months, The Times examined the life a...
# 15  Over six months, The Times examined the life a...
# 16  A study found that 49 percent of patients over...
# 17  Officials suspect that gang members have stole...
# 18  Dr. Jeffrey R. Burkes pleaded guilty in 2007 t...
# 19  Some readers claimed that the anti-overdose dr...
# 20  Dr. Stan Xuhui Li is accused of prescribing pa...
# 21  In a new approach to combating prescription pa...
# 22  Injections of steroids near the spine have bee...
# 23  The rising toll has cast a harsh light on the ...
# 24  The requirements for involuntary substance tre...
# 25  Researchers found that nearly two-thirds of ca...
# 26  A group of doctors and public health officials...
# 27  A city task force reported a 22 percent increa...
# 28  The shift toward painkillers is forcing policy...
# 29  The drug accounted for 1.7 percent of the 257 ...
# ..                                                ...
# 70  Children are pouring into the beleaguered chil...
# 71  Decimated by addiction, its heritage at risk, ...
# 72  As fentanyls enter the illegal drug supply in ...
# 73  Advocacy groups and the F.D.A. have warned tha...
# 74  President Trump trusts Ms. Conway. Is that eno...
# 75  It’s less costly to stop drug abuse before it ...
# 76  A federal judge in Ohio will oversee at least ...
# 77  One of America’s biggest rehab companies built...
# 78  Surgical patients can get as good or better pa...
# 79  Uganda has a strategy for giving scarce morphi...
# 80  State and local governments are giving up oppo...
# 81  A look at how opioids hijack the brain, from t...
# 82  Why do people use opioids? And why is it so ha...
# 83  In a new column, Prescribed Reading, Abigail Z...
# 84  Photographer Mark E. Trent chronicled the ever...
# 85  Officers say exposure to opioids during emerge...
# 86  Helping patients by making medicines is what w...
# 87  Federal prosecutors said the doctors unnecessa...
# 88  A reluctant evolution is taking place in resid...
# 89  We used video clips illustrated by software to...
# 90  The agency, whose oversight of opioid safety h...
# 91  Research found 85 percent more deaths among th...
# 92  Major league players will now be tested for op...
# 93  A new audit finds that the family directed $10...
# 94  Tufts University ordered that the Sackler fami...
# 95  The high school yearbook is a staple of Americ...
# 96  It’s true! Some tech companies had a positive ...
# 97  Morgan Stickney began training for the Paralym...
# 98  Nearly 27,000 children in Ohio were removed fr...
# 99  Today’s meth is far more potent than earlier v...
#
# [100 rows x 5 columns]

# %% [markdown]
# ## Saving our Corpus as Text Files for Further Analysis
#
# Now that we have the names and text for each article in one place, let's take the text data and save each article's text data as a seperate .txt file.

# %%
#Here we pull out only the filename and text columns from the table above.

subset = text_df[['name','text']]

# %%
#Here we make a list of tuples, which we can think of as a list of two elements joined, in this case the first element 
#being the article name and the second being its corresponding text.

tuples = [tuple(x) for x in subset.values]

# %%
tuples
# Out:
# [('Meier_2010',
#   'A review cited a higher risk of bone fracture, heart attack and death with use of narcotic-based drugs. Older patients with arthritis who take narcotic-based drugs to relieve pain face a higher risk of bone fracture, heart attack and death when compared to those taking non-narcotic drugs, according to a government-financed study published Monday.A review cited a higher risk of bone fracture, heart attack and death with use of narcotic-based drugs.'),
#  ('Zezima_2010',
#   'Workplace testing is drawing complaints from employees who say they should not be fired for taking legal drugs.LAWRENCEBURG, Tenn. \x97 The news, delivered in a phone call, left Sue Bates aghast: she was losing her job of 22 years after testing positive for a legally prescribed drug. Workplace testing is drawing complaints from employees who say they should not be fired for taking legal drugs.'),
#  ('Goodnough_2010',
#   'Drug users are breaking into people’s homes in search of prescription painkillers and other medications.BOSTON \x97 Police departments have collected thousands of handguns through buy-back programs in communities throughout the country. Now they want the contents of your medicine cabinet.Drug users are breaking into people’s homes in search of prescription painkillers and other medications.'),
#  ('Walter_2010',
#   'San Francisco police officers say they are seeing more elderly, sick or disabled people selling their medications on the street.In Gregory Watts’s 13 years as a San Francisco police officer, he has arrested countless drug dealers. But only recently did he begin to notice that many of them resembled his grandparents.San Francisco police officers say they are seeing more elderly, sick or disabled people selling their medications on the street.'),
#  ('Romm_2010',
#   'An expansive mix of medical reportage, history and memoir explores our relationship to pain.A simple understanding of pain would be this: It’s a biological response to injury or disease. Treat the cause and the pain abates. The body, after all, is a relatively efficient machine. But what happens when the wound won’t heal? And what if pain doesn’t stem from injury or disease, but is itself the problem?An expansive mix of medical reportage, history and memoir explores our relationship to pain.'),
#  ('Meier_2010',
#   'Regulators in Washington State are attempting to stem what some see as the excessive use of prescribed narcotics.In an unusual move, a state government is developing regulations meant to stop doctors from prescribing higher doses of powerful \x97 and often dangerous \x97 pain killers for patients who are not benefiting from them.Regulators in Washington State are attempting to stem what some see as the excessive use of prescribed narcotics.'),
#  ('Hevesi_2010',
#   'Mr. Lotsof’s belief that ibogaine could cure addiction to heroin persuaded the F.D.A. to approve a clinical trial, but the substance remains banned in the United States.Howard Lotsof was 19, addicted to heroin and searching for a new high in 1962 when he swallowed a bitter-tasting white powder taken from an exotic West African shrub. Mr. Lotsof’s belief that ibogaine could cure addiction to heroin persuaded the F.D.A. to approve a clinical trial, but the substance remains banned in the United States.'),
#  ('Rabin_2010',
#   'Emergency room visits for nonmedical use of prescription and over-the-counter drugs doubled during a recent five-year period.Emergency room visits for nonmedical use of prescription and over-the-counter drugs doubled during a recent five-year-period, the Centers for Disease Control and Prevention are reporting. Emergency room visits for nonmedical use of prescription and over-the-counter drugs doubled during a recent five-year period.'),
#  ('no_last_name_0_8_2010',
#   'Mysterious pain, doubting doctors, depression, fatigue and brain fog — six people speak about living with fibromyalgia.Mysterious pain, doubting doctors, depression, fatigue and brain fog — six people speak about living with fibromyalgia.Mysterious pain, doubting doctors, depression, fatigue and brain fog — six people speak about living with fibromyalgia.'),
#  ('Wilson_2010',
#   'The pain killer and related drugs can cause fatal heart rhythms.The painkilling drug propoxyphene, sold under the Darvon and Darvocet brands and used by about 10 million Americans last year, will be removed from the market because of serious heart risks, the Food and Drug Administration said on Friday.The pain killer and related drugs can cause fatal heart rhythms.'),
#  ('Bakalar_2011',
#   'Poisoning is now the leading cause of injury death, and 90 percent of poisonings were caused by drugs.In 2008, for the first time in nearly 30 years, more people died of poisoning than in car crashes. Poisoning is now the leading cause of injury death, and 90 percent of poisonings were caused by drugs. Poisoning is now the leading cause of injury death, and 90 percent of poisonings were caused by drugs.'),
#  ('Aschwanden_2011',
#   'More than 20 studies, including a large analysis of data on more than 200,000 children, have produced results that link acetaminophen use to an increased risk of asthma.THE HYPOTHESISMore than 20 studies, including a large analysis of data on more than 200,000 children, have produced results that link acetaminophen use to an increased risk of asthma.'),
#  ('Jackson_2011',
#   'The N.F.L. should appoint a league-wide medical body, unaffiliated with any team, to oversee the health care of its players.Los AngelesThe N.F.L. should appoint a league-wide medical body, unaffiliated with any team, to oversee the health care of its players.'),
#  ('Belson_2011',
#   'A dozen retired players contend that teams repeatedly administered the painkiller Toradol to them — worsening high-risk injuries like concussions — and failed to warn them of the consequences.In the latest lawsuit based on medical issues against the N.F.L., a dozen former players have accused the league and its teams of repeatedly administering the painkiller Toradol before and during games, worsening high-risk injuries like concussions.A dozen retired players contend that teams repeatedly administered the painkiller Toradol to them — worsening high-risk injuries like concussions — and failed to warn them of the consequences.'),
#  ('Branch_2011',
#   'Over six months, The Times examined the life and death of the hockey player Derek Boogaard. The second article of a three-part series explores the devastating toll of fighting on players. ‘I DIDN’T SEE it coming at all. I was in a bad position and he hit me hard, hardest I’ve ever been hit. I instantly knew it was broken. I didn’t lose consciousness, but I went straight on the ice. And I felt where it was, and my hand didn’t rub my face normally. It was a little chunky and sharp in spots and there was a hole there about the size of a fist.”  — TODD FEDORUK, former N.H.L. enforcer Over six months, The Times examined the life and death of the hockey player Derek Boogaard. The second article of a three-part series explores the devastating toll of fighting on players.'),
#  ('Branch_2011',
#   'Over six months, The Times examined the life and death of the hockey player Derek Boogaard. The first article of a three-part series revisits his childhood and his progression from boy to brawler.DEREK BOOGAARD was scared. He did not know whom he would fight, just that he must.Over six months, The Times examined the life and death of the hockey player Derek Boogaard. The first article of a three-part series revisits his childhood and his progression from boy to brawler.'),
#  ('Bakalar_2011',
#   'A study found that 49 percent of patients over age 75 were given pain medication, compared with about 65 percent of those under age 75.Older people who go to an emergency room in pain are less likely to get medication for it than younger people with similar levels of distress, a new analysis has found.A study found that 49 percent of patients over age 75 were given pain medication, compared with about 65 percent of those under age 75.'),
#  ('Kaplan_2011',
#   'Officials suspect that gang members have stolen blank prescription forms from New York City hospitals in a scheme to make money from addicts desperate for prescription painkillers.An unknown number of blank prescription forms have been stolen from New York City hospitals over the past several years in what investigators believe is a scheme by gang members to make money from addicts desperate for prescription painkillers.Officials suspect that gang members have stolen blank prescription forms from New York City hospitals in a scheme to make money from addicts desperate for prescription painkillers.'),
#  ('Wilson_2011',
#   'Dr. Jeffrey R. Burkes pleaded guilty in 2007 to writing illegal prescriptions for painkillers to a woman with whom he had had an affair. He now wants that plea thrown out.They met in 1986, the setting improbable for romance. She was blond and pretty, but she was in a dentist’s chair, and he was pulling out her wisdom teeth. Dr. Jeffrey R. Burkes pleaded guilty in 2007 to writing illegal prescriptions for painkillers to a woman with whom he had had an affair. He now wants that plea thrown out.'),
#  ('Szalavitz_2011',
#   'Some readers claimed that the anti-overdose drug Naloxone is not safe. Others, that drug users’ lives are not worth saving. Both claims are wrong.My column on making Naloxone available over-the-counter to reverse overdoses drew many plaudits and two main strands of criticism.\xa0 One group argued that addicts aren’t worth saving and we need to cut the drug supply; the other said that Naloxone, also known by its brand name, Narcan, is too risky to be available without a prescription.Some readers claimed that the anti-overdose drug Naloxone is not safe. Others, that drug users’ lives are not worth saving. Both claims are wrong.'),
#  ('Buettner_2012',
#   'Dr. Stan Xuhui Li is accused of prescribing pain medicine for medically unsound reasons to 20 patients, seven of whom have died.A doctor accused of running a prescription pain medication mill out of a basement office in Queens was charged with manslaughter on Thursday in the deaths of two former patients.Dr. Stan Xuhui Li is accused of prescribing pain medicine for medically unsound reasons to 20 patients, seven of whom have died.'),
#  ('Meier_2012',
#   'In a new approach to combating prescription painkiller abuse, the federal government is focusing on the middlemen between drug makers and the doctors and pharmacies that dispense drugs.A local druggist in Newport Beach, Calif., never expected that the federal government’s recent crackdown on distributors of prescription painkillers would ensnare him.In a new approach to combating prescription painkiller abuse, the federal government is focusing on the middlemen between drug makers and the doctors and pharmacies that dispense drugs.'),
#  ('Pollack_2012',
#   'Injections of steroids near the spine have been linked to other rare but devastating complications, including nerve damage, paralysis and strokes.Perry D. Clark says that a steroid injected near his spine to relieve persistent back pain instead left him “way, way worse.” Twelve years later, he still suffers from continuous stinging in his legs and feet and occasional bursts of excruciating pain. Injections of steroids near the spine have been linked to other rare but devastating complications, including nerve damage, paralysis and strokes.'),
#  ('Grady_2012',
#   'The rising toll has cast a harsh light on the loose regulations that legal experts say allowed a company to sell an unsafe drug to pain clinics.Eddie C. Lovelace, a Kentucky judge still on the bench into his late 70s, had a penchant for reciting Shakespeare from memory and telling funny stories in his big, booming voice. But a car accident last spring left him with severe neck pain, and in July and August he sought spinal injections with a steroid medicine for relief.The rising toll has cast a harsh light on the loose regulations that legal experts say allowed a company to sell an unsafe drug to pain clinics.'),
#  ('Christopher_2012',
#   'The requirements for involuntary substance treatment vary widely across the nation, causing the standard of care to differ dramatically from one place to the next.“I’m addicted to painkillers,” J., a thickset construction worker, told me on a recent afternoon in the emergency room, his wife at his side.The requirements for involuntary substance treatment vary widely across the nation, causing the standard of care to differ dramatically from one place to the next.'),
#  ('Chen_2012',
#   'Researchers found that nearly two-thirds of cancer patients said they were in pain or receiving pain medications, and roughly a third felt they needed more painkillers to fully treat their symptoms. Why aren’t doctors helping more?Recounting her father’s struggle with cancer was difficult for the young woman, even several years after his death. He’d endured first surgery and then chemotherapy and radiation, she told me, and the cancer had gone into remission. He was thrilled, but the aggressive treatment left him with chronic, debilitating pain. Once active, he struggled to get around in his own home.Researchers found that nearly two-thirds of cancer patients said they were in pain or receiving pain medications, and roughly a third felt they needed more painkillers to fully treat their symptoms. Why aren’t doctors helping more?'),
#  ('Meier_2012',
#   'A group of doctors and public health officials urged the government to curtail the use of prescription painkillers by changing labeling directions on how physicians should prescribe them.A group of doctors and public health officials urged the Food and Drug Administration on Wednesday to curtail the overuse and abuse of prescription painkillers by changing labeling directions on how and when physicians should prescribe them.A group of doctors and public health officials urged the government to curtail the use of prescription painkillers by changing labeling directions on how physicians should prescribe them.'),
#  ('Hartocollis_2012',
#   'A city task force reported a 22 percent increase in two years and called for legislation to better track prescriptions, with the goal of preventing drug abuse.The number of opioid painkiller prescriptions filled for New York City residents rose 22 percent in two years, to more than two million in 2010, according to data released Wednesday by a city panel.A city task force reported a 22 percent increase in two years and called for legislation to better track prescriptions, with the goal of preventing drug abuse.'),
#  ('Cave_2012',
#   'The shift toward painkillers is forcing policy makers to re-examine the expensive strategy of trying to stop illegal drugs from entering the United States.MEXICO CITY — America’s drug problem is shifting from illicit substances like cocaine to abuse of prescription painkillers, a change that is forcing policy makers to re-examine the long and expensive strategy of trying to stop illegal drugs from entering the United States. The shift toward painkillers is forcing policy makers to re-examine the expensive strategy of trying to stop illegal drugs from entering the United States.'),
#  ('Bakalar_2012',
#   'The drug accounted for 1.7 percent of the 257 million prescriptions written in 2009 for opioid pain relievers, but it was involved in 31.4 percent of overdose deaths.Methadone accounted for almost a third of the deaths caused by opioid pain relievers in 2009, even though it was prescribed far less often than other such drugs, government researchers have found.The drug accounted for 1.7 percent of the 257 million prescriptions written in 2009 for opioid pain relievers, but it was involved in 31.4 percent of overdose deaths.'),
#  ('Sontag_2013',
#   'In some areas, an unregulated clinic scene has sprung up for buprenorphine, a drug used to treat addiction, and it can pose a turbulent setting for patient care.PITTSBURGH — The patient is an addict. His doctor is an addict, too. Over the last decade, both men hit their own versions of rock bottom. For the patient, it was the concrete floor of a jail where he writhed in withdrawal. For the doctor, it was the food stamp office where, his career as a child psychiatrist in tatters, he ashamedly sought help.In some areas, an unregulated clinic scene has sprung up for buprenorphine, a drug used to treat addiction, and it can pose a turbulent setting for patient care.'),
#  ('Meier_2013',
#   'The experts are concerned that Zohydro is not formulated to halt abuse and is manufactured by a company that makes a treatment for people dependent on painkillers or alcohol.Addiction experts protested loudly when the Food and Drug Administration approved a powerful new opioid painkiller last month, saying that it would set off a wave of abuse much as OxyContin did when it first appeared.The experts are concerned that Zohydro is not formulated to halt abuse and is manufactured by a company that makes a treatment for people dependent on painkillers or alcohol.'),
#  ('Meier_2013',
#   'Lawyers for the city are investigating whether the benefits of the drugs, known as opioids, were overly promoted while their risks were underplayed.Lawyers for the city of Chicago are investigating marketing claims by producers of narcotic painkillers as a prelude to a possible lawsuit against them, according to interviews and a court filing.Lawyers for the city are investigating whether the benefits of the drugs, known as opioids, were overly promoted while their risks were underplayed.'),
#  ('no_last_name_3_3_2013',
#   'Two decisions by the F.D.A. show the challenges of dealing with the misuse of prescription drugs that contain hydrocodone.The Food and Drug Administration took an important step last week to curb an epidemic of overdose deaths from misuse of prescription painkillers that contain hydrocodone, such as Vicodin, Lortab and their generic equivalents, in combination with another painkilling drug. The only regret is that it took so long for the agency to make up its mind. Two decisions by the F.D.A. show the challenges of dealing with the misuse of prescription drugs that contain hydrocodone.'),
#  ('Meier_2013',
#   'The F.D.A.’s move to tighten restrictions for prescribing painkillers is a rare victory by lawmakers from states hard hit by prescription drug abuse over well-financed lobbyists for business and patient groups.When Heather Dougherty heard the news last week that the Food and Drug Administration had recommended tightening how doctors prescribed the most commonly used narcotic painkillers, she was overjoyed. Fourteen years earlier, her father, Dr. Ronald J. Dougherty, had filed a formal petition urging federal officials to crack down on the drugs.The F.D.A.’s move to tighten restrictions for prescribing painkillers is a rare victory by lawmakers from states hard hit by prescription drug abuse over well-financed lobbyists for business and patient groups.'),
#  ('Meier_2013',
#   'In a major shift, the Food and Drug Administration recommended new limits on prescriptions for widely abused narcotic painkillers like Vicodin and Lortab.The Food and Drug Administration on Thursday recommended tighter controls on how doctors prescribe the most commonly used narcotic painkillers, changes that are expected to take place as early as next year.In a major shift, the Food and Drug Administration recommended new limits on prescriptions for widely abused narcotic painkillers like Vicodin and Lortab.'),
#  ('Bakalar_2013',
#   'Black and Hispanic children who go to an E.R. with stomach pain are less likely than white children to receive pain medication and more likely to spend long hours in the emergency room, a new study reports.Black and Hispanic children who go to an emergency room with stomach pain are less likely than white children to receive pain medication, a new study reports, and more likely to spend long hours in the emergency room.Black and Hispanic children who go to an E.R. with stomach pain are less likely than white children to receive pain medication and more likely to spend long hours in the emergency room, a new study reports.'),
#  ('Bakalar_2013',
#   'A new review of studies suggests that injecting any liquid, even plain saline solution, works just as well as steroid injections for back pain.Injecting steroids into the area around the spinal cord, known as an epidural, is the most commonly used treatment for back pain, but a new review of studies suggests that injecting any liquid, even plain saline solution, works just as well. A new review of studies suggests that injecting any liquid, even plain saline solution, works just as well as steroid injections for back pain.'),
#  ('no_last_name_3_8_2013',
#   'The Food and Drug Administration’s new labeling rules leave consumers safer, but not safe enough.Consumers will be less apt to overdose on prescription painkillers — but still less safe than they should be — under new labeling rules announced by the Food and Drug Administration on Tuesday for a class of drugs known as opioid analgesics. The Food and Drug Administration’s new labeling rules leave consumers safer, but not safe enough.'),
#  ('Tavernise_2013',
#   'Federal officials said the labeling changes would “help improve the thoughtful prescribing” of medicines like OxyContin.WASHINGTON — The Food and Drug Administration on Tuesday announced changes to the labeling requirements for long-acting painkillers, in a further effort to curb prescription drug abuse, which has been on the rise in recent years.Federal officials said the labeling changes would “help improve the thoughtful prescribing” of medicines like OxyContin.'),
#  ('Frakt_2014',
#   'The current wave of problems caused by opioid drugs like OxyContin is the third in United States history. Balancing their risks and benefits has been a delicate task.Even as the Food and Drug Administration approves new, powerful opioid-based painkillers, the United States is in the midst of an epidemic of opioid overuse. This is not the first time.The current wave of problems caused by opioid drugs like OxyContin is the third in United States history. Balancing their risks and benefits has been a delicate task.'),
#  ('Bakalar_2016',
#   'Regular use of drugs like Advil or Tylenol for six years or longer may slightly increase the risk for hearing loss.Long term use of pain relievers may increase the risk for hearing loss, according to new findings.Regular use of drugs like Advil or Tylenol for six years or longer may slightly increase the risk for hearing loss.'),
#  ('Seelye_2016',
#   'The center, Hope on Haven Hill, provides drug treatment and counseling in a safe environment for opioid users who are pregnant or newly postpartum.ROCHESTER, N.H. — The young women, soon to be mothers, gathered around a big kitchen table, chatting excitedly about due dates and baby names and even morning sickness.The center, Hope on Haven Hill, provides drug treatment and counseling in a safe environment for opioid users who are pregnant or newly postpartum.'),
#  ('Goldman_2016',
#   '“I was really looking for a confrontation, so I could kill,” President Rodrigo Duterte of the Philippines told business leaders at a meeting in Manila.President Rodrigo Duterte of the Philippines, overseer of a contentious and bloody crackdown on drug dealers and users, boasted on Monday about having personally killed criminal suspects when he was mayor of Davao City.“I was really looking for a confrontation, so I could kill,” President Rodrigo Duterte of the Philippines told business leaders at a meeting in Manila.'),
#  ('Thomas_2016',
#   'According to the indictment, the employees, including the C.E.O., offered bribes to doctors to get them to prescribe more of the company’s product, Subsys.Federal prosecutors brought racketeering charges on Thursday against several former executives of Insys Therapeutics, a small Arizona drug company, saying they were part of a scheme that involved aggressive sales of the powerful and highly addictive pain drug fentanyl.According to the indictment, the employees, including the C.E.O., offered bribes to doctors to get them to prescribe more of the company’s product, Subsys.'),
#  ('Lachman_2017',
#   'Children are pouring into the beleaguered child welfare system.Our stunning failure to care for our most vulnerable children is a cause and devastating consequence of the opioid crisis that is ravaging towns around the country. We can’t end the crisis — or a host of other problems — until we fix our beleaguered child welfare system.Children are pouring into the beleaguered child welfare system.'),
#  ('Hoffman_2017',
#   'Decimated by addiction, its heritage at risk, the Cherokee Nation is trying to sue pharmacies and distributors. But it may be blocked from doing so.TAHLEQUAH, Okla. — Cherokee children were disappearing.Decimated by addiction, its heritage at risk, the Cherokee Nation is trying to sue pharmacies and distributors. But it may be blocked from doing so.'),
#  ('Katz_2017',
#   'As fentanyls enter the illegal drug supply in more places, overdose deaths rise, helping cause the first consecutive drop in U.S. life expectancy in half a century.As fentanyls enter the illegal drug supply in more places, overdose deaths rise, helping cause the first consecutive drop in U.S. life expectancy in half a century.As fentanyls enter the illegal drug supply in more places, overdose deaths rise, helping cause the first consecutive drop in U.S. life expectancy in half a century.'),
#  ('Kaplan_2017',
#   'Advocacy groups and the F.D.A. have warned that companies are capitalizing on the epidemic by offering unproven remedies.Chris Beekman, whose company sells the dietary supplement Opiate Detox Pro, does not understand what all the fuss is about.Advocacy groups and the F.D.A. have warned that companies are capitalizing on the epidemic by offering unproven remedies.'),
#  ('no_last_name_7_4_2017',
#   'President Trump trusts Ms. Conway. Is that enough to get something done on the opioid addiction crisis?Kellyanne Conway, counselor to President Trump, has no public health background, a reputation for bending the truth, and a knack for generating government ethics complaints. Yet Ms. Conway does have the ear of the president. She has also studied America’s opioid epidemic in recent months as part of her portfolio. She is not the “opioids czar,” as some news outlets reported this week, but her stepping out as point person on the government response to this public health crisis stirred hope of concrete action from a White House that so far has offered little more than talk.President Trump trusts Ms. Conway. Is that enough to get something done on the opioid addiction crisis?'),
#  ('Frakt_2017',
#   'It’s less costly to stop drug abuse before it starts, and there are ways to do that. It’s a shame that President Trump’s opioid commission said little about demand-side prevention.It’s less costly to stop drug abuse before it starts, and there are ways to do that. '),
#  ('Smith_2017',
#   'A federal judge in Ohio will oversee at least 189 of the cases filed by local governments against companies that make or distribute prescription opioids.AKRON, Ohio — Citing a spike in overdose deaths, growing demands for drug treatment and a strained budget, officials here in Summit County filed a lawsuit late Wednesday against companies that make or distribute prescription opioids. On Monday, Smith County in Tennessee did the same. And on Tuesday, nine cities and counties in Michigan announced similar suits.A federal judge in Ohio will oversee at least 189 of the cases filed by local governments against companies that make or distribute prescription opioids.'),
#  ('Corkery_2017',
#   'One of America’s biggest rehab companies built an empire. But after a patient named Gary Benefield died, its enemies — investors and business rivals alike — struck hard.One of America’s biggest rehab companies built an empire. But after a patient named Gary Benefield died, its enemies — investors and business rivals alike — struck hard.One of America’s biggest rehab companies built an empire. But after a patient named Gary Benefield died, its enemies — investors and business rivals alike — struck hard.'),
#  ('Bakalar_2017',
#   'Surgical patients can get as good or better pain relief with a fraction of the amount of opioids typically prescribed.Surgical patients can get as good or better pain relief with a fraction of the amount of opioids typically prescribed, a group of doctors reports.Surgical patients can get as good or better pain relief with a fraction of the amount of opioids typically prescribed.'),
#  ('McNeil_2017',
#   'Uganda has a strategy for giving scarce morphine to patients in pain. But many poor nations won’t emulate it, over fear of an opioid epidemic.KAMPALA, Uganda — Pain is only the latest woe in John Bizimungu’s life.Uganda has a strategy for giving scarce morphine to patients in pain. But many poor nations won’t emulate it, over fear of an opioid epidemic.'),
#  ('Meier_2018',
#   'State and local governments are giving up opportunities to hold the drug industry accountable for Americans’ overdose deaths.When the Justice Department in 2007 settled its criminal case against the maker of OxyContin, a high-powered painkiller, federal officials claimed a “victory” that would deter other companies from illegally marketing opioids.State and local governments are giving up opportunities to hold the drug industry accountable for Americans’ overdose deaths.'),
#  ('Sinha_2018',
#   'A look at how opioids hijack the brain, from temptation and tolerance to relapse and recovery.A look at how opioids hijack the brain, from temptation and tolerance to relapse and recovery.A look at how opioids hijack the brain, from temptation and tolerance to relapse and recovery.'),
#  ('Harlan_2018',
#   'Why do people use opioids? And why is it so hard for them to stop? We invited readers to share their experiences.Every 11 minutes, another life in the United States is lost to an opioid overdose. The epidemic affects old and young, rich and poor. It stretches across genders, races and state lines. And every year the crisis has grown deadlier.Why do people use opioids? And why is it so hard for them to stop? We invited readers to share their experiences.'),
#  ('Zuger_2018',
#   'In a new column, Prescribed Reading, Abigail Zuger looks at past books that dealt with opioid abuse in order to understand better how we got here.Medical knowledge is evolving at warp speed, spinning out reams of new information into sound bites, articles and more and more new health books to overload your sagging shelves.In a new column, Prescribed Reading, Abigail Zuger looks at past books that dealt with opioid abuse in order to understand better how we got here.'),
#  ('no_last_name_8_4_2018',
#   'Photographer Mark E. Trent chronicled the everyday lives of friends who were addicted to drugs. Some survived. Others did not.Photographer Mark E. Trent chronicled the everyday lives of friends who were addicted to drugs. Some survived. Others did not.Photographer Mark E. Trent chronicled the everyday lives of friends who were addicted to drugs. Some survived. Others did not.'),
#  ('Smith_2018',
#   'Officers say exposure to opioids during emergencies can put them in mortal danger. Doctors say their symptoms may just be the “nocebo” effect.ALTON, N.H. — Eric Weil, a gregarious 50-year-old painter who lives in a wooded neighborhood hugging the shores of Lake Winnipesaukee, never suspected he would face felony charges when he called 911 last August.Officers say exposure to opioids during emergencies can put them in mortal danger. Doctors say their symptoms may just be the “nocebo” effect.'),
#  ('no_last_name_8_6_2018',
#   'Helping patients by making medicines is what we do at Purdue Pharma, and it was the principle upon which physician brothers founded the company.Helping patients by making medicines is what we do at Purdue Pharma, and it was the principle upon which physician brothers founded the company.'),
#  ('None_2018',
#   'Federal prosecutors said the doctors unnecessarily prescribed opioids to patients and sought to defraud insurance companies.Six Michigan doctors have been charged with insurance fraud and unnecessarily prescribing opioids to patients in a $464 million scheme, according to court documents filed this week by federal prosecutors.Federal prosecutors said the doctors unnecessarily prescribed opioids to patients and sought to defraud insurance companies.'),
#  ('Goodnough_2018',
#   'A reluctant evolution is taking place in residential drug treatment for opioid addiction. Here’s a look at one center’s wary shift.MURFREESBORO, Tenn. — Just past a cemetery along a country road, an addiction treatment center called JourneyPure at the River draws hundreds of patients a month who are addicted to opioids and other drugs. They divide their days between therapy sessions, songwriting, communing with horses and climbing through a treetop ropes course. After dinner, they’re driven into town in white vans for 12-step meetings.A reluctant evolution is taking place in residential drug treatment for opioid addiction. Here’s a look at one center’s wary shift.'),
#  ('Symonds_2018',
#   'We used video clips illustrated by software to interpret heroin addicts’ own words about their experiences.Times Insider delivers behind-the-scenes insights into how news, features and opinion come together at The New York Times.We used video clips illustrated by software to interpret heroin addicts’ own words about their experiences.'),
#  ('Goodnough_2019',
#   'The agency, whose oversight of opioid safety has largely eluded scrutiny, did not improve flawed programs designed to reduce addiction and overdoses, documents show.WASHINGTON — Newly unearthed documents show that the Food and Drug Administration failed to use its policing powers to make sure a program to curb improper prescribing of opioids was effective, researchers say. The agency, whose oversight of opioid safety has largely eluded scrutiny, did not improve flawed programs designed to reduce addiction and overdoses, documents show.'),
#  ('Chokshi_2019',
#   'Research found 85 percent more deaths among those of prime working age in places where car factories closed compared with where they stayed open.The last two decades have brought both a sharp decline in automaking jobs in the United States and the rise of a deadly epidemic of opioid abuse. According to a new study, the two trends may well be related. Research found 85 percent more deaths among those of prime working age in places where car factories closed compared with where they stayed open.'),
#  ('Wagner_2019',
#   'Major league players will now be tested for opioids and cocaine, but violators will be evaluated for treatment programs rather than immediately punished.SAN DIEGO — After a season that saw the opioid-overdose death of a 27-year-old pitcher, Major League Baseball and the players’ union on Thursday announced that players will be tested for opioids and cocaine starting in spring training under an updated drug policy. Major league players will now be tested for opioids and cocaine, but violators will be evaluated for treatment programs rather than immediately punished.'),
#  ('Hoffman_2019',
#   'A new audit finds that the family directed $10.7 billion from the drugmaker to family-controlled trusts and holding companies, as legal pressure tightened around Purdue.As scrutiny of Purdue Pharma’s role in the opioid epidemic intensified during the past dozen years, its owners, members of the Sackler family, withdrew more than $10 billion from the company, distributing it among trusts and overseas holding companies, according to a new audit commissioned by Purdue.A new audit finds that the family directed $10.7 billion from the drugmaker to family-controlled trusts and holding companies, as legal pressure tightened around Purdue.'),
#  ('Barry_2019',
#   'Tufts University ordered that the Sackler family name be removed from five facilities and programs, but said it would not return donations or rescind an honorary degree.BOSTON — Tufts University removed the Sackler name from five facilities and programs on Thursday over the family’s role in the opioid epidemic, a gesture aimed at distancing the institution from a pharmaceutical dynasty closely tied to the school for 40 years. Tufts University ordered that the Sackler family name be removed from five facilities and programs, but said it would not return donations or rescind an honorary degree.'),
#  ('Levin_2019',
#   'The high school yearbook is a staple of American teenage life. But for some, it also is a reminder of failed dreams, lost opportunities and the sheer toll of the opioid crisis.The high school yearbook is a staple of American teenage life. But for some, it also is a reminder of failed dreams, lost opportunities and the sheer toll of the opioid crisis.The high school yearbook is a staple of American teenage life. But for some, it also is a reminder of failed dreams, lost opportunities and the sheer toll of the opioid crisis.'),
#  ('Roose_2019',
#   'It’s true! Some tech companies had a positive social impact this year.Two years ago, I started what has become one of my favorite annual traditions. Instead of a year-end column rounding up all the dubious and objectionable things technology companies did over the last year — a true fish-in-a-barrel assignment — I highlighted some examples of “good tech.” I wanted to give kudos to the kinds of tech projects that don’t always make headlines but that improve people’s lives in tangible ways.It’s true! Some tech companies had a positive social impact this year.'),
#  ('Waldstein_2019',
#   'Morgan Stickney began training for the Paralympics after having her left leg amputated below the knee. But a familiar pain struck again.The New York Times Sports department is revisiting the subjects of some compelling articles from the last year or so. Here is our March report on Morgan Stickney’s first recovery. Morgan Stickney began training for the Paralympics after having her left leg amputated below the knee. But a familiar pain struck again.'),
#  ('Levin_2019',
#   'Nearly 27,000 children in Ohio were removed from their homes last year, many because of the opioid crisis. More than a quarter were placed in the care of relatives.PORTSMOUTH, Ohio — Hannah Thurman’s new life began with her father’s murder. Nearly 27,000 children in Ohio were removed from their homes last year, many because of the opioid crisis. More than a quarter were placed in the care of relatives.'),
#  ('Goodnough_2019',
#   'Today’s meth is far more potent than earlier versions, but because it isn’t an opioid, many federal addiction treatment funds can’t be used to fight it.TULSA, Okla. — The teenager had pink cheeks from the cold and a matter-of-fact tone as she explained why she had started using methamphetamine after becoming homeless last year.Today’s meth is far more potent than earlier versions, but because it isn’t an opioid, many federal addiction treatment funds can’t be used to fight it.')]

# %%
#Here we move through our list of tuples, telling the computer to open a new file, take the first element filename 
#in the tuple to name it as, and then take the second element (the text) in the tuple and write it into the newly
#created file.

#This code works through the list and saves each article as a sepearte file in the folder where this jupyter notebook
#is located. This is how the corpus and text files you were sent via email and that are available on the github page
#were created.

for tup in tuples:
    f=open(str(tup[0])+".txt","w+")
    f.write(str(tup[1]))
    f.close()
